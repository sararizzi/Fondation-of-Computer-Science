# %%
import pandas as pd # Pandas library to manipulate the dataframe 
from datetime import timedelta # datetime library to manage time

# %%
trips = pd.read_csv('data.csv', dtype = {'store_and_fwd_flag': str}) # Importing the data with Pandas read_csv (), column 6 had mixed types so we converted the column type as object and filled null values as unknown    
trips.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2         1.0                  N           238           239
# 1            1.2         1.0                  N           239           238
# 2            0.6         1.0                  N           238           238
# 3            0.8         1.0                  N           238           151
# 4            0.0         1.0                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           1.0          6.0    3.0      0.5        1.47           0.0
# 1           1.0          7.0    3.0      0.5        1.50           0.0
# 2           1.0          6.0    3.0      0.5        1.00           0.0
# 3           1.0          5.5    0.5      0.5        1.36           0.0
# 4           2.0          3.5    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3         11.27                   2.5
# 1                    0.3         12.30                   2.5
# 2                    0.3         10.80                   2.5
# 3                    0.3          8.16                   0.0
# 4                    0.3          4.80                   0.0

# %%
trips['store_and_fwd_flag'] = trips['store_and_fwd_flag'].fillna('Unknown') # column 6 had mixed types so we converted the column type as object and filled null values as unknown

# %% [markdown]
# # 1) Extract all trips with trip_distance larger than 50

# %%
dfifty = trips[trips['trip_distance'] > 50] # from the column 'trip_distance' we obtain all the rows with distance larger than 50
dfifty
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 23842         2.0  2020-01-01 01:53:07   2020-01-01 03:54:41              1.0
# 39013         2.0  2020-01-01 02:05:07   2020-01-01 03:03:10              1.0
# 41620         1.0  2020-01-01 03:05:54   2020-01-01 04:16:26              1.0
# 58262         2.0  2020-01-01 05:36:12   2020-01-01 06:40:06              1.0
# 63024         2.0  2020-01-01 07:40:30   2020-01-01 08:40:01              1.0
# ...           ...                  ...                   ...              ...
# 6326169       2.0  2020-01-31 22:47:26   2020-01-31 23:49:14              1.0
# 6331181       2.0  2020-01-31 23:45:36   2020-02-01 01:00:25              5.0
# 6333801       2.0  2020-01-31 23:24:16   2020-02-01 01:32:56              1.0
# 6397132       NaN  2020-01-28 11:54:00   2020-01-28 19:35:00              NaN
# 6398446       NaN  2020-01-28 07:37:00   2020-01-28 08:42:00              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 23842            52.30         5.0                  N           262
# 39013            51.23         5.0                  N           264
# 41620            53.80         5.0                  N           132
# 58262            55.23         5.0                  N           132
# 63024            54.19         5.0                  N           132
# ...                ...         ...                ...           ...
# 6326169          51.83         5.0                  N           132
# 6331181          57.99         4.0                  N           107
# 6333801          52.97         4.0                  N           264
# 6397132          60.36         NaN            Unknown            17
# 6398446      210240.07         NaN            Unknown            76
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 23842             265           1.0       300.00   0.00      0.0       61.78
# 39013             264           1.0       329.00   0.00      0.5      100.78
# 41620             265           1.0       250.00   0.00      0.0       53.35
# 58262             265           2.0       170.00   0.00      0.5        0.00
# 63024             265           1.0       230.00   0.00      0.0        0.00
# ...               ...           ...          ...    ...      ...         ...
# 6326169           265           1.0       220.00   0.00      0.5       48.96
# 6331181           265           1.0       245.00   0.50      0.5       38.24
# 6333801           265           1.0       227.00   0.50      0.5       46.16
# 6397132            61           NaN        12.04   0.00      0.5        0.00
# 6398446           231           NaN        37.77   2.75      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 23842            6.12                    0.3        370.70
# 39013            6.12                    0.3        436.70
# 41620           16.62                    0.3        320.27
# 58262           18.26                    0.3        189.06
# 63024           12.24                    0.3        242.54
# ...               ...                    ...           ...
# 6326169         23.99                    0.3        293.75
# 6331181          6.12                    0.3        293.16
# 6333801          0.00                    0.3        276.96
# 6397132         12.24                    0.3         25.08
# 6398446          0.00                    0.3         41.32
#
#          congestion_surcharge
# 23842                     2.5
# 39013                     0.0
# 41620                     0.0
# 58262                     0.0
# 63024                     0.0
# ...                       ...
# 6326169                   0.0
# 6331181                   2.5
# 6333801                   2.5
# 6397132                   0.0
# 6398446                   0.0
#
# [379 rows x 18 columns]

# %% [markdown]
# # 2) Extract all trips where payment_type is missing

# %%
trips[trips['payment_type'].isna()].head() # by using the pandas function .isna() we detect missing values in the column 'payment_type'
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6339567       NaN  2020-01-01 08:51:00   2020-01-01 09:19:00              NaN
# 6339568       NaN  2020-01-01 08:38:43   2020-01-01 08:51:08              NaN
# 6339569       NaN  2020-01-01 08:27:00   2020-01-01 08:32:00              NaN
# 6339570       NaN  2020-01-01 08:46:00   2020-01-01 08:57:00              NaN
# 6339571       NaN  2020-01-01 08:21:00   2020-01-01 08:38:00              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 6339567          13.69         NaN            Unknown           136
# 6339568           3.42         NaN            Unknown           121
# 6339569           2.20         NaN            Unknown           197
# 6339570           0.84         NaN            Unknown           262
# 6339571           7.24         NaN            Unknown            45
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 6339567           232           NaN        51.05   2.75      0.5         0.0
# 6339568             9           NaN        27.06   2.75      0.0         0.0
# 6339569           216           NaN        24.36   2.75      0.5         0.0
# 6339570           236           NaN        26.08   2.75      0.5         0.0
# 6339571           142           NaN        25.28   2.75      0.5         0.0
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 6339567           0.0                    0.3         54.60
# 6339568           0.0                    0.3         30.11
# 6339569           0.0                    0.3         27.91
# 6339570           0.0                    0.3         29.63
# 6339571           0.0                    0.3         28.83
#
#          congestion_surcharge
# 6339567                   0.0
# 6339568                   0.0
# 6339569                   0.0
# 6339570                   0.0
# 6339571                   0.0

# %% [markdown]
# # 3) For each (PULocationID, DOLocationID) pair, determine the number of trips

# %%
# we group by 'PULocationID', 'DOLocationID' using the function 'groupby' and the function .size() to obtain the number of trips for each group
# .reset_index(name = '') resets the index of the dataframe and names the new created column.
trips.groupby(['PULocationID', 'DOLocationID']).size().reset_index(name = 'Number of trips')
# Out:
#        PULocationID  DOLocationID  Number of trips
# 0                 1             1              638
# 1                 1            50                1
# 2                 1            68                1
# 3                 1           138                2
# 4                 1           140                1
# ...             ...           ...              ...
# 31272           265           259                2
# 31273           265           261                1
# 31274           265           263                4
# 31275           265           264              317
# 31276           265           265             2508
#
# [31277 rows x 3 columns]

# %% [markdown]
# # 4) Save all rows with missing VendorID, passenger_count, store_and_fwd_flag, payment_type in a new dataframe called bad, and remove those rows from the original dataframe.

# %%
# we use .isnull() and .any(axis = 1)(any row that satifies the condition) to create the dataframe with all trips having null values in the specified columns indicated
nullValue = trips[trips[['VendorID', 'passenger_count', 'store_and_fwd_flag', 'payment_type']].isnull().any(axis=1)]
nullValue
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6339567       NaN  2020-01-01 08:51:00   2020-01-01 09:19:00              NaN
# 6339568       NaN  2020-01-01 08:38:43   2020-01-01 08:51:08              NaN
# 6339569       NaN  2020-01-01 08:27:00   2020-01-01 08:32:00              NaN
# 6339570       NaN  2020-01-01 08:46:00   2020-01-01 08:57:00              NaN
# 6339571       NaN  2020-01-01 08:21:00   2020-01-01 08:38:00              NaN
# ...           ...                  ...                   ...              ...
# 6405003       NaN  2020-01-31 22:51:00   2020-01-31 23:22:00              NaN
# 6405004       NaN  2020-01-31 22:10:00   2020-01-31 23:26:00              NaN
# 6405005       NaN  2020-01-31 22:50:07   2020-01-31 23:17:57              NaN
# 6405006       NaN  2020-01-31 22:25:53   2020-01-31 22:48:32              NaN
# 6405007       NaN  2020-01-31 22:44:00   2020-01-31 23:06:00              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 6339567          13.69         NaN            Unknown           136
# 6339568           3.42         NaN            Unknown           121
# 6339569           2.20         NaN            Unknown           197
# 6339570           0.84         NaN            Unknown           262
# 6339571           7.24         NaN            Unknown            45
# ...                ...         ...                ...           ...
# 6405003           3.24         NaN            Unknown           237
# 6405004          22.13         NaN            Unknown           259
# 6405005          10.51         NaN            Unknown           137
# 6405006           5.49         NaN            Unknown            50
# 6405007          11.60         NaN            Unknown           179
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 6339567           232           NaN        51.05   2.75      0.5         0.0
# 6339568             9           NaN        27.06   2.75      0.0         0.0
# 6339569           216           NaN        24.36   2.75      0.5         0.0
# 6339570           236           NaN        26.08   2.75      0.5         0.0
# 6339571           142           NaN        25.28   2.75      0.5         0.0
# ...               ...           ...          ...    ...      ...         ...
# 6405003           234           NaN        17.59   2.75      0.5         0.0
# 6405004            45           NaN        46.67   2.75      0.5         0.0
# 6405005           169           NaN        48.85   2.75      0.0         0.0
# 6405006            42           NaN        27.17   2.75      0.0         0.0
# 6405007           205           NaN        54.56   2.75      0.5         0.0
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 6339567          0.00                    0.3         54.60
# 6339568          0.00                    0.3         30.11
# 6339569          0.00                    0.3         27.91
# 6339570          0.00                    0.3         29.63
# 6339571          0.00                    0.3         28.83
# ...               ...                    ...           ...
# 6405003          0.00                    0.3         21.14
# 6405004         12.24                    0.3         62.46
# 6405005          0.00                    0.3         51.90
# 6405006          0.00                    0.3         30.22
# 6405007          0.00                    0.3         58.11
#
#          congestion_surcharge
# 6339567                   0.0
# 6339568                   0.0
# 6339569                   0.0
# 6339570                   0.0
# 6339571                   0.0
# ...                       ...
# 6405003                   0.0
# 6405004                   0.0
# 6405005                   0.0
# 6405006                   0.0
# 6405007                   0.0
#
# [65441 rows x 18 columns]

# %%
# with the function .index we obtain the 'bad' rows index  and delete them from the original dataframe
trips = trips.drop(nullValue.index)
trips
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 6339562       2.0  2020-01-31 23:38:07   2020-01-31 23:52:21              1.0
# 6339563       2.0  2020-01-31 23:00:18   2020-01-31 23:19:18              1.0
# 6339564       2.0  2020-01-31 23:24:22   2020-01-31 23:40:39              1.0
# 6339565       2.0  2020-01-31 23:44:22   2020-01-31 23:54:00              1.0
# 6339566       2.0  2020-01-31 23:19:37   2020-01-31 23:20:41              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.20         1.0                  N           238
# 1                 1.20         1.0                  N           239
# 2                 0.60         1.0                  N           238
# 3                 0.80         1.0                  N           238
# 4                 0.00         1.0                  N           193
# ...                ...         ...                ...           ...
# 6339562           2.10         1.0                  N           163
# 6339563           2.13         1.0                  N           164
# 6339564           2.55         1.0                  N            79
# 6339565           1.61         1.0                  N           100
# 6339566           0.00         1.0                  N           193
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 239           1.0          6.0    3.0      0.5        1.47
# 1                 238           1.0          7.0    3.0      0.5        1.50
# 2                 238           1.0          6.0    3.0      0.5        1.00
# 3                 151           1.0          5.5    0.5      0.5        1.36
# 4                 193           2.0          3.5    0.5      0.5        0.00
# ...               ...           ...          ...    ...      ...         ...
# 6339562           246           1.0         11.0    0.5      0.5        2.96
# 6339563            79           1.0         13.0    0.5      0.5        3.36
# 6339564            68           1.0         12.5    0.5      0.5        3.26
# 6339565           142           2.0          8.5    0.5      0.5        0.00
# 6339566           193           1.0          0.0    0.0      0.0        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                 0.0                    0.3         11.27
# 1                 0.0                    0.3         12.30
# 2                 0.0                    0.3         10.80
# 3                 0.0                    0.3          8.16
# 4                 0.0                    0.3          4.80
# ...               ...                    ...           ...
# 6339562           0.0                    0.3         17.76
# 6339563           0.0                    0.3         20.16
# 6339564           0.0                    0.3         19.56
# 6339565           0.0                    0.3         12.30
# 6339566           0.0                    0.0          0.00
#
#          congestion_surcharge
# 0                         2.5
# 1                         2.5
# 2                         2.5
# 3                         0.0
# 4                         0.0
# ...                       ...
# 6339562                   2.5
# 6339563                   2.5
# 6339564                   2.5
# 6339565                   2.5
# 6339566                   0.0
#
# [6339567 rows x 18 columns]

# %% [markdown]
# #  5)  Add a duration column storing how long each trip has taken (use tpep_pickup_datetime, tpep_dropoff_datetime)

# %%
# we substract the 'pickup_datetime' from the 'dropoff_datetime' to know how long each trip has taken
trips['duration'] = pd.to_datetime(trips['tpep_dropoff_datetime']) - pd.to_datetime(trips['tpep_pickup_datetime'])

# %%
trips.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2         1.0                  N           238           239
# 1            1.2         1.0                  N           239           238
# 2            0.6         1.0                  N           238           238
# 3            0.8         1.0                  N           238           151
# 4            0.0         1.0                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           1.0          6.0    3.0      0.5        1.47           0.0
# 1           1.0          7.0    3.0      0.5        1.50           0.0
# 2           1.0          6.0    3.0      0.5        1.00           0.0
# 3           1.0          5.5    0.5      0.5        1.36           0.0
# 4           2.0          3.5    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge        duration
# 0                    0.3         11.27                   2.5 0 days 00:04:48
# 1                    0.3         12.30                   2.5 0 days 00:07:25
# 2                    0.3         10.80                   2.5 0 days 00:06:11
# 3                    0.3          8.16                   0.0 0 days 00:04:51
# 4                    0.3          4.80                   0.0 0 days 00:02:18

# %% [markdown]
# # 6) For each pickup location, determine how many trips have started there.

# %%
# The same procedure as the 3rd point but grouping bu 'PULocationID' and naming the new created column 'trip_count'
trips.groupby('PULocationID').size().reset_index(name='trip_count') # if we want to count null values aswell
# Out:
#      PULocationID  trip_count
# 0               1         753
# 1               2           3
# 2               3          70
# 3               4        9902
# 4               5          39
# ..            ...         ...
# 255           261       34229
# 256           262       85591
# 257           263      123997
# 258           264       43779
# 259           265        3090
#
# [260 rows x 2 columns]

# %% [markdown]
# # 7) Cluster the pickup time of the day into 30-minute intervals (e.g. from 02:00 to 02:30)

# %%
trips['parsed date'] = pd.to_datetime(trips['tpep_pickup_datetime'])
trips['minutes'] = trips['parsed date'].dt.hour * 60 + trips['parsed date'].dt.minute   #tranform time in minutes
trips['tpep_pickup_datetime_intervals'] = trips['minutes'] // 30      #dividing for 30 to create the slices
trips.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2         1.0                  N           238           239
# 1            1.2         1.0                  N           239           238
# 2            0.6         1.0                  N           238           238
# 3            0.8         1.0                  N           238           151
# 4            0.0         1.0                  N           193           193
#
#    payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# 0           1.0  ...      0.5        1.47           0.0
# 1           1.0  ...      0.5        1.50           0.0
# 2           1.0  ...      0.5        1.00           0.0
# 3           1.0  ...      0.5        1.36           0.0
# 4           2.0  ...      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge        duration  \
# 0                    0.3         11.27                   2.5 0 days 00:04:48
# 1                    0.3         12.30                   2.5 0 days 00:07:25
# 2                    0.3         10.80                   2.5 0 days 00:06:11
# 3                    0.3          8.16                   0.0 0 days 00:04:51
# 4                    0.3          4.80                   0.0 0 days 00:02:18
#
#           parsed date minutes tpep_pickup_datetime_intervals
# 0 2020-01-01 00:28:15      28                              0
# 1 2020-01-01 00:35:39      35                              1
# 2 2020-01-01 00:47:41      47                              1
# 3 2020-01-01 00:55:23      55                              1
# 4 2020-01-01 00:01:58       1                              0
#
# [5 rows x 22 columns]

# %% [markdown]
# # 8) For each interval, determine the average number of passengers and the average fare amount.

# %%
# we obtain the average number of passengers and the average fare amount by using .mean() and grouping by 'tpep_pickup_datetime_intervals'
interAvg = trips.groupby('tpep_pickup_datetime_intervals')[['passenger_count' , 'fare_amount']].mean().reset_index()
# we rename the columns using .rename() function
interAvg = interAvg.rename(columns={'passenger_count':'Avg_passenger','fare_amount':'Avg_fare_amount'})
interAvg.head()
# Out:
#    tpep_pickup_datetime_intervals  Avg_passenger  Avg_fare_amount
# 0                               0       1.572848        13.526433
# 1                               1       1.584345        13.214132
# 2                               2       1.578933        12.699554
# 3                               3       1.589182        12.265997
# 4                               4       1.587479        12.089669

# %% [markdown]
# # 9) For each payment type and each interval, determine the average fare amount

# %%
# Same procedure as we did previously
tripsAvg = trips.groupby(['payment_type', 'tpep_pickup_datetime_intervals'])['fare_amount'].mean().reset_index(name='avg_fare_amount')
tripsAvg
# Out:
#      payment_type  tpep_pickup_datetime_intervals  avg_fare_amount
# 0             1.0                               0        13.869142
# 1             1.0                               1        13.472232
# 2             1.0                               2        12.824603
# 3             1.0                               3        12.357974
# 4             1.0                               4        12.008589
# ..            ...                             ...              ...
# 188           4.0                              44         1.533326
# 189           4.0                              45        -0.787090
# 190           4.0                              46        -0.351277
# 191           4.0                              47        -2.748432
# 192           5.0                              35         0.000000
#
# [193 rows x 3 columns]

# %% [markdown]
# # 10) For each payment type, determine the interval when the average fare amount is maximum

# %%
# By using the previous dataframe, we group by 'payment_type' and get the id (interval) of the maximum 'avg_fare_amount
# In the dataframe result we store the corresponding rows through the ids 
maxid = tripsAvg.groupby('payment_type')['avg_fare_amount'].idxmax()
result = tripsAvg.loc[maxid]
result
# Out:
#      payment_type  tpep_pickup_datetime_intervals  avg_fare_amount
# 10            1.0                              10        21.256949
# 58            2.0                              10        14.846814
# 110           3.0                              14        10.950938
# 154           4.0                              10         6.634043
# 192           5.0                              35         0.000000

# %% [markdown]
# # 11) For each payment type, determine the interval when the overall ratio between the tip and the fare amounts is maximum

# %%
#add column ratio
trips['ratio'] = trips['tip_amount']/trips['fare_amount']

#remove row with nan or inf value
trips_cleaned = trips.dropna(subset=['ratio'])
trips_cleaned = trips_cleaned[~trips_cleaned['ratio'].isin([float('inf'), float('-inf')])]
trips_cleaned[['tip_amount', 'fare_amount', 'ratio']]
# Out:
#          tip_amount  fare_amount     ratio
# 0              1.47          6.0  0.245000
# 1              1.50          7.0  0.214286
# 2              1.00          6.0  0.166667
# 3              1.36          5.5  0.247273
# 4              0.00          3.5  0.000000
# ...             ...          ...       ...
# 6339561        4.26         17.5  0.243429
# 6339562        2.96         11.0  0.269091
# 6339563        3.36         13.0  0.258462
# 6339564        3.26         12.5  0.260800
# 6339565        0.00          8.5  0.000000
#
# [6336826 rows x 3 columns]

# %%
#for each payment_type and intervals i found the max ratio
max_ratio = trips_cleaned.groupby(["payment_type" , "tpep_pickup_datetime_intervals"])["ratio"].mean().reset_index()
#find the interval with max ratio for each payment type
max_ratio = max_ratio.loc[max_ratio.groupby("payment_type")["ratio"].idxmax()]
max_ratio
# Out:
#      payment_type  tpep_pickup_datetime_intervals     ratio
# 3             1.0                               3  0.503453
# 66            2.0                              18  0.000051
# 138           3.0                              42  0.023336
# 164           4.0                              20  0.007890

# %% [markdown]
# # 12) Find the location with the highest average fare amount

# %%
# Average fare amount for each PULocation and DOLocation
meanDO = trips.groupby('DOLocationID')['fare_amount'].mean()
meanPU = trips.groupby('PULocationID')['fare_amount'].mean()

print(f"For pickup the location with higehest average is: {meanPU.idxmax()} with avg fare {meanPU.max()}")
print(f"For dropoff the location with higehest average is: {meanDO.idxmax()} with avg fare {meanDO.max()}")

if (meanDO.max() > meanPU.max()):
    print(f"The location with the higehest average fare amount is: {meanDO.idxmax()}")
else:
    print(f"The location with the higehest average fare amount is: {meanPU.idxmax()}")
# Out:
# For pickup the location with higehest average is: 204 with avg fare 107.0
# For dropoff the location with higehest average is: 44 with avg fare 86.77377049180328
# The location with the higehest average fare amount is: 204

# %% [markdown]
# # 13) Build a new dataframe (called common) where, for each pickup location we keep all trips to the 5 most common destinations (i.e. each pickup location can have different common destinations).

# %%
#find for each cople (PULocationID, DOLocationID) the number of trip made
counter = trips.groupby(['PULocationID', 'DOLocationID']).size().reset_index(name='count').sort_values(by=['PULocationID','count'], ascending=[True, False])
counter
# Out:
#        PULocationID  DOLocationID  count
# 0                 1             1    636
# 8                 1           264    105
# 9                 1           265      4
# 3                 1           138      2
# 1                 1            50      1
# ...             ...           ...    ...
# 26445           265           241      1
# 26446           265           243      1
# 26449           265           248      1
# 26451           265           259      1
# 26452           265           261      1
#
# [26456 rows x 3 columns]

# %%
# take for each PULocationID (groupby) the top 5 destination (head(5))
top_destinations = counter.groupby('PULocationID').head(5)
top_destinations.dropna()
# Out:
#        PULocationID  DOLocationID  count
# 0                 1             1    636
# 8                 1           264    105
# 9                 1           265      4
# 3                 1           138      2
# 1                 1            50      1
# ...             ...           ...    ...
# 26455           265           265   2496
# 26454           265           264    317
# 26357           265             1     76
# 26370           265            48     18
# 26399           265           132      8
#
# [1260 rows x 3 columns]

# %%
# Merge with original dataset to get the trips that has 'PULocationID' and 'DOLocationID' in the list of the top 5
common = trips.merge(top_destinations[['PULocationID', 'DOLocationID']], on=['PULocationID', 'DOLocationID'])
common
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             2.0  2020-01-01 00:24:22   2020-01-01 00:25:54              1.0
# 2             2.0  2020-01-01 00:46:46   2020-01-01 00:49:17              1.0
# 3             1.0  2020-01-01 00:17:53   2020-01-01 00:22:47              1.0
# 4             2.0  2020-01-01 00:49:45   2020-01-01 00:54:12              1.0
# ...           ...                  ...                   ...              ...
# 1956034       2.0  2020-01-31 12:33:49   2020-01-31 12:59:52              1.0
# 1956035       1.0  2020-01-31 14:20:50   2020-01-31 15:13:20              1.0
# 1956036       1.0  2020-01-31 19:13:35   2020-01-31 19:25:46              1.0
# 1956037       2.0  2020-01-31 19:39:19   2020-01-31 19:39:28              2.0
# 1956038       2.0  2020-01-31 20:16:10   2020-01-31 20:20:15              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.20         1.0                  N           238
# 1                 0.56         1.0                  N           238
# 2                 0.62         1.0                  N           238
# 3                 0.80         1.0                  Y           238
# 4                 0.86         1.0                  N           238
# ...                ...         ...                ...           ...
# 1956034           9.59         1.0                  N           109
# 1956035           0.00         1.0                  N            46
# 1956036           3.50         1.0                  N            57
# 1956037           0.11         5.0                  N           204
# 1956038           0.72         1.0                  N            73
#
#          DOLocationID  payment_type  ...  tip_amount  tolls_amount  \
# 0                 239           1.0  ...        1.47          0.00
# 1                 239           1.0  ...        1.70          0.00
# 2                 239           1.0  ...        1.00          0.00
# 3                 239           1.0  ...        1.85          0.00
# 4                 239           1.0  ...        1.86          0.00
# ...               ...           ...  ...         ...           ...
# 1956034             5           1.0  ...        0.00          0.00
# 1956035            61           1.0  ...        0.00          6.12
# 1956036            95           1.0  ...        2.95          0.00
# 1956037           204           1.0  ...        0.00          0.00
# 1956038             9           1.0  ...        0.00          0.00
#
#          improvement_surcharge  total_amount  congestion_surcharge  \
# 0                          0.3         11.27                   2.5
# 1                          0.3          9.00                   2.5
# 2                          0.3          9.30                   2.5
# 3                          0.3         11.15                   2.5
# 4                          0.3         11.16                   2.5
# ...                        ...           ...                   ...
# 1956034                    0.3         30.80                   0.0
# 1956035                    0.3         56.12                   0.0
# 1956036                    0.3         17.75                   0.0
# 1956037                    0.3        107.80                   0.0
# 1956038                    0.3          6.30                   0.0
#
#                duration         parsed date  minutes  \
# 0       0 days 00:04:48 2020-01-01 00:28:15       28
# 1       0 days 00:01:32 2020-01-01 00:24:22       24
# 2       0 days 00:02:31 2020-01-01 00:46:46       46
# 3       0 days 00:04:54 2020-01-01 00:17:53       17
# 4       0 days 00:04:27 2020-01-01 00:49:45       49
# ...                 ...                 ...      ...
# 1956034 0 days 00:26:03 2020-01-31 12:33:49      753
# 1956035 0 days 00:52:30 2020-01-31 14:20:50      860
# 1956036 0 days 00:12:11 2020-01-31 19:13:35     1153
# 1956037 0 days 00:00:09 2020-01-31 19:39:19     1179
# 1956038 0 days 00:04:05 2020-01-31 20:16:10     1216
#
#         tpep_pickup_datetime_intervals     ratio
# 0                                    0  0.245000
# 1                                    0  0.485714
# 2                                    1  0.222222
# 3                                    0  0.336364
# 4                                    1  0.338182
# ...                                ...       ...
# 1956034                             25  0.000000
# 1956035                             28  0.000000
# 1956036                             38  0.226923
# 1956037                             39  0.000000
# 1956038                             40  0.000000
#
# [1956039 rows x 23 columns]

# %% [markdown]
# # 14) On the common dataframe, for each payment type and each interval, determine the average fare amount

# %%
# As done previously, we use the groupby function with the mean() function and name the newly created column as 'com_avg_fare'
commonAvg = common.groupby(['payment_type', 'tpep_pickup_datetime_intervals'])['fare_amount'].mean().reset_index(name='com_avg_fare')
commonAvg
# Out:
#      payment_type  tpep_pickup_datetime_intervals  com_avg_fare
# 0             1.0                               0      8.588957
# 1             1.0                               1      8.690681
# 2             1.0                               2      8.496143
# 3             1.0                               3      8.026808
# 4             1.0                               4      7.945909
# ..            ...                             ...           ...
# 188           4.0                              44      1.300119
# 189           4.0                              45     -0.563944
# 190           4.0                              46     -2.568571
# 191           4.0                              47     -4.409173
# 192           5.0                              35      0.000000
#
# [193 rows x 3 columns]

# %% [markdown]
# # 15) Compute the difference of the average fare amount computed in the previous point with those computed at point 9.

# %%
# To compute the difference we merge the two dataframes on 'payment_type' and 'tpep_pickup_datetime_intervals' 
mergeAvg = pd.merge(commonAvg, tripsAvg, on = ['payment_type', 'tpep_pickup_datetime_intervals'], how = 'inner')
# Calculate the difference of the two columns obtained
mergeAvg['diff_avg'] = mergeAvg['com_avg_fare'] - mergeAvg['avg_fare_amount']
mergeAvg
# Out:
#      payment_type  tpep_pickup_datetime_intervals  com_avg_fare  \
# 0             1.0                               0      8.588957
# 1             1.0                               1      8.690681
# 2             1.0                               2      8.496143
# 3             1.0                               3      8.026808
# 4             1.0                               4      7.945909
# ..            ...                             ...           ...
# 188           4.0                              44      1.300119
# 189           4.0                              45     -0.563944
# 190           4.0                              46     -2.568571
# 191           4.0                              47     -4.409173
# 192           5.0                              35      0.000000
#
#      avg_fare_amount  diff_avg
# 0          13.869142 -5.280185
# 1          13.472232 -4.781551
# 2          12.824603 -4.328460
# 3          12.357974 -4.331167
# 4          12.008589 -4.062679
# ..               ...       ...
# 188         1.533326 -0.233207
# 189        -0.787090  0.223146
# 190        -0.351277 -2.217294
# 191        -2.748432 -1.660740
# 192         0.000000  0.000000
#
# [193 rows x 5 columns]

# %% [markdown]
# # 16) Compute the ratio between the differences computed in the previous point and those computed in point 9. Note: you have to compute a ratio for each pair (payment type, interval).

# %%
# Using the previous dataframe we compute the ratio column as 'diff_avg' divided by 'avg_fare_amount' for each pair
mergeAvg['ratio'] = mergeAvg['diff_avg'] / mergeAvg['avg_fare_amount']
mergeAvg
# Out:
#      payment_type  tpep_pickup_datetime_intervals  com_avg_fare  \
# 0             1.0                               0      8.588957
# 1             1.0                               1      8.690681
# 2             1.0                               2      8.496143
# 3             1.0                               3      8.026808
# 4             1.0                               4      7.945909
# ..            ...                             ...           ...
# 188           4.0                              44      1.300119
# 189           4.0                              45     -0.563944
# 190           4.0                              46     -2.568571
# 191           4.0                              47     -4.409173
# 192           5.0                              35      0.000000
#
#      avg_fare_amount  diff_avg     ratio
# 0          13.869142 -5.280185 -0.380715
# 1          13.472232 -4.781551 -0.354919
# 2          12.824603 -4.328460 -0.337512
# 3          12.357974 -4.331167 -0.350475
# 4          12.008589 -4.062679 -0.338314
# ..               ...       ...       ...
# 188         1.533326 -0.233207 -0.152092
# 189        -0.787090  0.223146 -0.283508
# 190        -0.351277 -2.217294  6.312096
# 191        -2.748432 -1.660740  0.604250
# 192         0.000000  0.000000       NaN
#
# [193 rows x 6 columns]

# %% [markdown]
# # 17) Build chains of trips. Two trips are consecutive in a chain if (a) they have the same VendorID, (b) the pickup location of the second trip  is also the dropoff location of the first trip, (c) the pickup time of the second trip is after the dropoff time of the first trip, and (d) the pickup time of the second trip is at most 2 minutes later than the dropoff time of the first trip.

# %%
# Keep only the needed columns and only the rows without nan values
reduced = trips[['VendorID', 'PULocationID', 'DOLocationID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime']]
reduced = reduced.dropna()

reduced['tpep_pickup_datetime'] = pd.to_datetime(reduced['tpep_pickup_datetime'])
reduced['tpep_dropoff_datetime'] = pd.to_datetime(reduced['tpep_dropoff_datetime'])

# Order rows by 'vendorID' and 'tpep_pickup_datetime', the preceding rows of a current analyzed trip will have less pickup time
reduced = reduced.sort_values(by=['VendorID', 'tpep_pickup_datetime'], ascending=[True, True])

reduced
# Out:
#          VendorID  PULocationID  DOLocationID tpep_pickup_datetime  \
# 8483          1.0            68           170  2020-01-01 00:00:00
# 3083          1.0            79           162  2020-01-01 00:00:03
# 5760          1.0           264            68  2020-01-01 00:00:05
# 5050          1.0            75            75  2020-01-01 00:00:07
# 2555          1.0           145           179  2020-01-01 00:00:25
# ...           ...           ...           ...                  ...
# 4269480       2.0           236           262  2020-07-10 11:34:11
# 4282277       2.0           236            43  2020-07-31 18:50:41
# 275044        2.0           142           161  2021-01-02 00:22:00
# 275045        2.0           170           148  2021-01-02 00:44:08
# 275046        2.0            90           148  2021-01-02 01:12:10
#
#         tpep_dropoff_datetime
# 8483      2020-01-01 00:13:03
# 3083      2020-01-01 00:13:04
# 5760      2020-01-01 00:26:30
# 5050      2020-01-01 00:03:26
# 2555      2020-01-01 00:05:59
# ...                       ...
# 4269480   2020-07-10 11:42:41
# 4282277   2020-07-31 18:54:12
# 275044    2021-01-02 00:36:50
# 275045    2021-01-02 00:58:56
# 275046    2021-01-02 01:25:01
#
# [6339567 rows x 5 columns]

# %%
import time
# This function allows to find all precedents trips (that match the pre-fixed conditions) of current_trip
def find_valid_trips(reduced, current_trip, i):

    # Search the valid trips only in the previous row (only in the rows that have already been analized)
    valid_trips = reduced.iloc[:i]
    # The past trips must certainly have arrived no more than two minutes earlier if we want a match (current_trip['tpep_pickup_datetime'] - timedelta(minutes=2) >= reduced['tpep_dropoff_datetime'])
    #if they arrived first there is no need to keep them in the database because going forward they will certainly not have matches (dataset is sorted by PU time)
    #with loc and with this condition we delete the unusefull rows (the one that has wrong DO time)
    reduced = reduced.loc[current_trip['tpep_pickup_datetime'] - timedelta(minutes=2) >= reduced['tpep_dropoff_datetime'],:]

    # Search the trips that meet the conditions
    valid_trips = valid_trips[
    (current_trip['PULocationID'] == valid_trips['DOLocationID']) &
    (current_trip['tpep_pickup_datetime'] > valid_trips['tpep_dropoff_datetime']) &
    ((current_trip['tpep_pickup_datetime'] - valid_trips['tpep_dropoff_datetime']) < timedelta(minutes=2))
    ]

    # Extract the indices of these trips
    valid_trip_indices = valid_trips.index.tolist()
    
    return valid_trip_indices

# This function allows to update the dictionary with the trip sequences
def update_chain(chains_dict, valid_trips, current_trip):

    # For each trip identified as preceding the current trip, update the found sequences
    for past_trip in valid_trips:

        # If a valid preceding trip exists, the chain is extended. If not, a new chain is created
        # It means that in the dictionary there is a sequence that ends with that journey
        if past_trip in chains_dict:
            # Add current_trip at the existing chain
            chains_dict[past_trip].append(current_trip.name)
            # Update the key, key contains the last trip of the chain
            chains_dict[current_trip.name] = chains_dict.pop(past_trip)
            return
        # If past trip isn't already in the chain, a new chain is created
        else:
            # The new chain will contain the index of past trip followed by the index of current_trip
            chains_dict[current_trip.name] = [past_trip, current_trip.name]

# Start building the dictionary with the chains
# The dictionary contains a sequence of trips and each sequence key is the last trip(id) of the sequence (es. sequence [55, 67] has key = 67)
chains = {}
reduced = reduced.head(100000)

# For each vendorID
for vendor_id in reduced['VendorID'].unique():
    reduced = reduced[reduced['VendorID'] == vendor_id] 

    # Analyze each row
    for i in range(len(reduced) - 1):

        #current trip is the row being analyzed
        current_trip = reduced.iloc[i]

        # Use the function to find all trips that may precede the current_trip
        valid_trips = find_valid_trips(reduced, current_trip, i)

        # If we have some valid trips we need to update the found sequences
        if len(valid_trips)>0:
            #with this function we update the sequences in the dictionary
            update_chain(chains, valid_trips, current_trip)
                
# No need of dictionary keys anymore 
all_chains = list(chains.values())
print('le sequenze trovate sono: ' , len(all_chains))
print('le sequenze sono: ', all_chains[0:100], '...')
# Out:
# le sequenze trovate sono:  30019
# le sequenze sono:  [[1487, 5364], [7236, 1779], [1939, 1940], [11128, 941], [2282, 8443], [2958, 11339], [5938, 5448], [12247, 4174], [12247, 3009], [11017, 7075], [11680, 8970], [3515, 918], [1206, 10652], [615, 10504], [654, 10732], [11017, 5371], [12247, 1442], [4003, 10986], [1206, 8087], [12297, 1112, 228], [654, 4308], [4669, 6055], [10582, 7774], [13018, 11766], [409, 6548], [2936, 10941], [1206, 8784], [5321, 1333], [2940, 1924], [1073, 1074], [3374, 9945], [1073, 966], [409, 2381], [10039, 8491], [2575, 1012], [12932, 1747], [5321, 9397], [2575, 11936], [8858, 1287], [1112, 3671], [5969, 5040], [12217, 535], [9251, 6187, 762], [1028, 10905], [8255, 7354], [5246, 978], [8483, 11105], [8255, 7637], [6187, 2077], [5089, 6563], [11366, 1834], [11366, 12188], [12238, 8294], [4381, 3419], [5246, 5247], [284, 2489], [2477, 6230], [11568, 6554], [2477, 10442], [8483, 12479, 9284], [7156, 1727], [4339, 582], [5172, 11696], [1018, 1690], [7156, 4273], [4817, 9201], [11346, 1423], [4817, 8346], [6900, 9059], [9058, 579], [6310, 3999], [7393, 1272], [2788, 100], [1236, 7482, 6387], [2788, 4452], [12431, 11317], [4253, 8586, 10198], [6341, 9034], [10552, 9488], [10534, 6141], [9135, 12420], [11246, 670], [12479, 120, 1043], [8639, 11348], [8558, 11612], [1732, 12735], [11246, 11172], [7169, 11662], [1732, 7700], [2571, 9005, 2551], [6108, 6232], [5321, 12303, 11740], [1236, 5313, 10912], [869, 5896, 7512], [5516, 2224], [10162, 2483, 10017], [9910, 595, 7170], [5797, 285], [9005, 5314], [4097, 7517]] ...

# %%
from collections import defaultdict

number_to_sequences = defaultdict(list)
found_duplicate = False

# Find all the numbers in the sequences
for idx, sequence in enumerate(all_chains[:100]):
    first_number = sequence[0]  # Consider only the first number of the sequence
    number_to_sequences[first_number].append(idx)

    # Check if the first number is already in more than one sequence
    if len(number_to_sequences[first_number]) > 1:
        duplicate_sequences = [all_chains[i] for i in number_to_sequences[first_number]]
        print(f"Number {first_number} is in more than one sequence: {duplicate_sequences}")
        found_duplicate = True
        break

if not found_duplicate:
    print("No duplicates")
# Out:
# Number 12247 is in more than one sequence: [[12247, 4174], [12247, 3009]]
# Number 795157 is in more than one sequence:  [[795157, 809376], [795157, 809070, 809683, 807177]]
# Number 794804 is in more than one sequence:  [[783827, 787218, 791498, 793797, 794804, 794128, 803548, 798064, 803502, 805922], [794804, 798579, 806568, 813591, 806952]]
# Number 798064 is in more than one sequence:  [[783827, 787218, 791498, 793797, 794804, 794128, 803548, 798064, 803502, 805922], [798064, 793365, 806247, 804792, 804453, 804693, 808865, 818159]]
# Number 797926 is in more than one sequence:  [[797926, 805243], [791714, 796509, 803385, 802026, 794972, 801829, 797600, 797926, 804140, 810947, 804085, 808381]]
# Number 804910 is in more than one sequence:  [[800055, 804910, 804217], [804910, 808507]]
# Number 784659 is in more than one sequence:  [[784659, 783402, 794343, 794344, 800226, 812493], [784659, 786831, 793384, 808052, 806522, 811904, 805663, 806015, 808902]]
# Number 799111 is in more than one sequence:  [[793985, 799116, 800370, 799110, 795209, 799111, 809702], [799111, 805526, 813042]]
# Number 801463 is in more than one sequence:  [[790133, 787498, 794906, 801463, 804006], [801463, 803813], [801463, 810617, 808549, 806948], [801463, 813526, 811929, 805335, 805336]]
# Number 801252 is in more than one sequence:  [[801252, 807646, 806400], [772275, 782217, 774608, 787345, 787396, 793963, 801252, 797506, 813112, 813771, 804862, 811334, 803988, 816336, 817971]]
# Number 794131 is in more than one sequence:  [[794131, 808566], [794131, 804116, 804320], [790278, 790749, 782558, 796335, 793647, 801779, 798071, 794131, 809755, 810898, 813483, 807360]]
# Number 799620 is in more than one sequence:  [[799620, 810194], [799620, 807478, 810850, 807052], [797298, 799620, 812360, 807804, 809345, 813532, 809300]]
# Number 802162 is in more than one sequence:  [[796256, 802162, 811639], [802162, 812765]]
# Number 793832 is in more than one sequence:  [[783372, 798617, 793832, 793053, 812381], [793832, 795303, 810388], [793832, 796138, 803136, 810192]]
# Number 797812 is in more than one sequence:  [[790613, 803722, 797812, 795325, 795359, 813234, 809368], [797812, 796738, 797925, 797676, 806608, 804938], [797812, 794173, 801979, 804097, 804549, 805672, 811430, 822257]]
# Number 813234 is in more than one sequence:  [[790613, 803722, 797812, 795325, 795359, 813234, 809368], [813234, 812695], [813234, 812877, 810407], [813234, 803828, 805943]]
# Number 808019 is in more than one sequence:  [[808019, 813056], [808019, 807254, 811757], [783862, 798848, 808019, 813495, 806460, 803882]]
# Number 793504 is in more than one sequence:  [[794115, 800938, 799813, 798340, 793504, 803963], [793504, 809948, 805848], [793504, 810878, 813264]]
# Number 795619 is in more than one sequence:  [[785254, 795619, 812222], [795619, 804790, 807626, 804431, 819947]]
# Number 794124 is in more than one sequence:  [[794124, 798843, 793720, 808264], [794124, 796662, 797220, 810715, 814237]]
# Number 798940 is in more than one sequence:  [[801298, 798940, 813654], [798940, 808569], [798940, 808362], [798940, 813152], [798940, 809034, 806817, 809595], [798940, 808294, 805004, 809655, 820973, 821325, 823694, 827111]]
# Number 804880 is in more than one sequence:  [[804880, 806038], [804880, 804386], [796443, 800046, 801106, 795186, 801780, 804880, 803956, 807882]]
# Number 797653 is in more than one sequence:  [[797645, 797653, 810949], [797653, 804056, 805923], [797653, 806033, 805964]]
# Number 800264 is in more than one sequence:  [[800264, 793282, 804566], [793404, 802992, 801818, 800264, 798751, 807112]]
# Number 798278 is in more than one sequence:  [[782747, 792256, 803051, 795852, 798278, 799989, 803763, 807881], [798278, 793430, 794199, 808805, 809893, 805594]]
# Number 800535 is in more than one sequence:  [[794930, 796341, 793712, 800535, 813196], [800535, 809348, 807580, 811616, 804485]]
# Number 802210 is in more than one sequence:  [[802210, 803984], [802210, 809486], [797386, 802209, 802210, 811963, 811246]]
# Number 797974 is in more than one sequence:  [[783361, 791784, 791363, 783076, 790360, 800229, 798253, 793938, 797974, 796697, 811432], [797974, 803378, 799425, 811919, 804015]]
# Number 797220 is in more than one sequence:  [[794124, 796662, 797220, 810715, 814237], [797220, 812177, 804831, 818534]]
# Number 795828 is in more than one sequence:  [[795828, 804424], [795828, 805980, 808690, 813073, 811367, 804908]]
# Number 796938 is in more than one sequence:  [[795034, 793668, 793669, 796938, 807644], [796938, 803924]]
# Number 794036 is in more than one sequence:  [[797886, 802270, 797599, 792973, 794036, 807744], [794036, 804287, 806899, 807746, 812371, 810322, 819893, 822658, 820900]]
# Number 797087 is in more than one sequence:  [[797405, 802642, 797087, 794574, 810372], [797087, 799090, 810539, 811703]]
# Number 806931 is in more than one sequence:  [[795716, 793796, 798487, 806931, 809457], [806931, 809994, 810126]]
# Number 806596 is in more than one sequence:  [[800385, 799760, 795822, 806596, 806597], [806596, 804329], [806596, 809701], [806596, 811468], [806596, 814027]]
# Number 808016 is in more than one sequence:  [[801216, 808016, 813980], [808016, 810432, 811843, 809902, 807455]]
# Number 793195 is in more than one sequence:  [[793195, 801185, 813266], [800677, 796609, 793195, 794139, 808632, 804575], [793195, 793123, 807886, 813113, 804123], [793195, 796621, 810461, 810188, 813770, 814407, 818334, 816079]]
# Number 793857 is in more than one sequence:  [[790710, 794255, 798605, 802514, 793857, 807723], [793857, 808392, 810442]]
# Number 793687 is in more than one sequence:  [[793687, 801334, 800683, 801160, 794326, 810630], [793687, 793664, 795400, 811702, 809703], [799334, 793687, 802411, 807782, 810640, 814971, 814609]]
# Number 805389 is in more than one sequence:  [[797074, 805389, 803941], [805389, 809049], [805389, 808664]]
# Number 808484 is in more than one sequence:  [[808484, 813896], [796089, 797148, 803573, 808484, 808082, 810631]]
# Number 801979 is in more than one sequence:  [[801979, 804533], [801979, 808021, 813406, 809526, 810081], [797812, 794173, 801979, 804097, 804549, 805672, 811430, 822257]]
# Number 797054 is in more than one sequence:  [[797054, 802753, 798324, 810383, 812406], [798655, 799402, 797054, 794461, 793469, 793422, 814024, 813160, 803913, 809541, 804283, 808343, 813766, 823165]]
# Number 800661 is in more than one sequence:  [[800661, 807757], [782817, 785357, 794503, 803673, 793068, 800661, 813718, 804012, 805880, 812899, 807022, 817664]]
# Number 793987 is in more than one sequence:  [[793987, 806019], [793987, 808282], [793987, 811188, 804477], [793987, 810930, 808272], [793987, 806451, 812756], [793192, 793987, 806721, 810006, 805021]]
# Number 813365 is in more than one sequence:  [[813365, 813366], [813365, 806142, 803898, 804698], [787245, 801962, 796985, 813365, 808778, 810713, 812989, 809882, 820400], [813365, 806458, 808763, 810746, 809484, 820845, 817468, 816379]]
# Number 809162 is in more than one sequence:  [[798416, 809162, 808322], [809162, 812921], [809162, 813589, 813362]]
# Number 801262 is in more than one sequence:  [[801262, 807570], [801262, 805968], [801262, 804275], [801262, 808824, 803806, 804535, 820249]]
# Number 799394 is in more than one sequence:  [[799464, 799394, 804195], [799394, 813099, 813301, 810501, 810478, 806144]]
# Number 810030 is in more than one sequence:  [[786121, 800598, 810030, 806932], [810030, 812037]]
# Number 805526 is in more than one sequence:  [[799111, 805526, 813042], [805526, 806090], [805526, 812569, 810820, 806143], [805526, 810488, 807061, 810254, 804830, 814125]]
# Number 805720 is in more than one sequence:  [[795099, 805720, 806766], [805720, 813008, 805234]]
# Number 807767 is in more than one sequence:  [[807767, 810406], [798967, 807767, 804306, 808213, 807531], [807767, 803823, 813703, 816527]]
# Number 796589 is in more than one sequence:  [[795568, 796589, 800554, 804581], [796589, 802740, 812675, 811753, 807248]]
# Number 809001 is in more than one sequence:  [[809001, 806521], [809001, 805668, 804481]]
# Number 808881 is in more than one sequence:  [[808881, 804399], [808881, 808212], [808881, 814361, 806045, 804478], [808881, 808485, 805625]]
# Number 807914 is in more than one sequence:  [[807914, 808411], [807914, 805352, 807412, 806069, 807064], [796609, 793431, 805979, 807914, 806529, 812591, 813058, 804953, 805050, 820470]]
# Number 810061 is in more than one sequence:  [[802220, 794236, 794237, 810061, 813901], [810061, 804590], [810061, 804991, 807113, 810009, 813723, 805084, 809998, 821694], [810061, 806679, 805468, 807049, 811120, 823158]]
# Number 799733 is in more than one sequence:  [[799733, 798958, 810998], [799032, 799733, 802050, 798282, 796959, 799319, 806947], [799733, 803748, 797577, 795951, 808001, 812936], [799733, 801368, 793025, 802126, 796445, 809342, 806355, 808383, 816590]]
# Number 798958 is in more than one sequence:  [[799733, 798958, 810998], [798958, 804451], [798958, 804034], [798958, 813883, 810812], [798958, 804121, 815895, 823648, 814456, 829428]]
# Number 796609 is in more than one sequence:  [[800677, 796609, 793195, 794139, 808632, 804575], [796609, 797860, 810146, 812727], [796609, 793431, 805979, 807914, 806529, 812591, 813058, 804953, 805050, 820470]]
# Number 798082 is in more than one sequence:  [[793965, 802244, 793939, 802409, 798082, 813064, 805301], [798082, 810139, 810561, 807826, 807581, 805589, 818440]]
# Number 807201 is in more than one sequence:  [[807201, 806411], [800419, 807201, 807202, 808221]]
# Number 801759 is in more than one sequence:  [[801759, 793843, 810946, 804445], [795005, 795810, 799572, 801759, 797048, 794721, 810867, 812898]]
# Number 799155 is in more than one sequence:  [[799155, 801314, 808792], [798816, 799155, 794833, 814018]]
# Number 801314 is in more than one sequence:  [[799155, 801314, 808792], [801314, 811481, 809687]]
# Number 796342 is in more than one sequence:  [[796342, 805125], [796342, 810384], [796342, 809567, 812299], [796342, 806222, 811049, 806079], [801978, 802531, 794613, 796342, 811113, 804907, 803959, 807591]]
# Number 796544 is in more than one sequence:  [[794435, 796544, 810037], [796544, 808233, 808206, 805771, 808568, 809052, 816849, 821359, 823509]]
# Number 809117 is in more than one sequence:  [[809117, 803996], [809117, 808220], [793296, 803282, 794870, 809117, 803970, 812729]]
# Number 796977 is in more than one sequence:  [[796977, 805871], [796977, 808986, 803878, 811788], [802514, 796977, 809191, 809211, 804426, 811714]]
# Number 795951 is in more than one sequence:  [[795951, 807529, 804825], [799733, 803748, 797577, 795951, 808001, 812936], [795951, 806542, 807656], [795951, 808989, 807650, 810645, 813812], [795951, 808914, 806305, 804157, 812823, 821665]]
# Number 813160 is in more than one sequence:  [[813160, 814366], [813160, 804707, 812633, 813231], [813160, 804282, 813897, 806046, 806249], [813160, 812423, 806658, 804724], [798655, 799402, 797054, 794461, 793469, 793422, 814024, 813160, 803913, 809541, 804283, 808343, 813766, 823165]]
# Number 802922 is in more than one sequence:  [[802922, 794665, 795656, 803001, 797266, 804627], [787395, 788873, 802922, 796991, 800706, 800707, 802749, 807152, 809591, 808691, 804412, 805493, 805506, 817410, 819065, 821823, 820555, 823072]]
# Number 798454 is in more than one sequence:  [[796444, 798454, 795092, 797009, 793605, 813482, 809999], [798454, 794612, 802532, 793110, 809960, 807530]]
# Number 783082 is in more than one sequence:  [[787538, 787539, 783082, 796812, 814239], [783082, 801298, 797639, 806323, 809945], [783082, 793635, 807464, 813195, 809404, 821312]]
# Number 793430 is in more than one sequence:  [[798278, 793430, 794199, 808805, 809893, 805594], [793430, 795385, 807051]]
# Number 807234 is in more than one sequence:  [[783356, 785362, 802967, 802304, 795178, 797610, 797113, 812840, 807234, 810035], [807234, 810819, 808727], [807234, 807235, 808393, 814130]]
# Number 803123 is in more than one sequence:  [[792090, 803123, 797077, 806236], [803123, 793517, 809265], [803123, 795174, 804183, 804806, 808377, 804118, 804119]]
# Number 809960 is in more than one sequence:  [[798454, 794612, 802532, 793110, 809960, 807530], [809960, 814384, 805295, 809446, 810776]]
# Number 794633 is in more than one sequence:  [[794633, 809233], [796789, 802384, 794633, 813403, 812368, 815273, 814799]]
# Number 808670 is in more than one sequence:  [[808670, 807571], [799558, 796683, 808670, 812784, 807118, 812938]]
# Number 791737 is in more than one sequence:  [[767141, 767577, 780636, 781260, 792625, 791737, 793646, 797264, 794206, 801500, 811949, 809781], [791737, 794147, 796333, 800973, 793718, 799230, 803026, 803842, 809934]]
# Number 805407 is in more than one sequence:  [[805407, 805890], [805407, 809127], [793719, 801618, 805407, 812172, 808180], [805407, 807310, 808911], [805407, 805411, 814319, 809349, 806231, 804482, 813025]]
# Number 797792 is in more than one sequence:  [[787303, 785470, 795044, 796177, 795113, 797792, 805322], [797792, 804240], [797792, 805733]]
# Number 794844 is in more than one sequence:  [[794844, 796541, 803798, 813161], [800932, 793561, 794844, 802995, 804211, 810302, 805235, 804033, 806543, 805227]]
# Number 803798 is in more than one sequence:  [[794844, 796541, 803798, 813161], [803798, 809540]]
# Number 796194 is in more than one sequence:  [[779854, 782884, 788400, 785071, 791385, 785819, 784958, 799060, 797979, 793429, 793012, 796194, 802321, 803271, 805491, 809118], [796194, 802108, 800709, 809761, 813776], [796194, 800411, 800412, 794411, 811010]]
# Number 800599 is in more than one sequence:  [[787245, 802269, 800599, 814232], [800599, 809904], [800599, 806112], [800599, 805431], [800599, 809768], [800599, 804370, 814403]]
# Number 802262 is in more than one sequence:  [[802262, 809697], [802262, 805291], [796990, 796789, 797568, 802262, 810570, 811429, 810425], [802262, 807329, 808508, 804225, 803879], [802262, 812004, 810174, 823832]]
# Number 813112 is in more than one sequence:  [[813112, 811617], [813112, 808269], [813112, 812225, 804110, 811149], [772275, 782217, 774608, 787345, 787396, 793963, 801252, 797506, 813112, 813771, 804862, 811334, 803988, 816336, 817971], [813112, 804505, 810238, 807480, 820222, 820745, 815013, 814935]]
# Number 810139 is in more than one sequence:  [[810139, 810140], [810139, 810323, 804747, 808181], [798082, 810139, 810561, 807826, 807581, 805589, 818440], [810139, 808009, 805001, 807231, 806023, 819132], [810139, 813700, 804738, 810502, 804649, 814416, 819980]]
# Number 808617 is in more than one sequence:  [[790329, 790025, 782838, 785499, 793023, 795560, 800586, 793036, 798578, 803632, 808617, 810910], [808617, 805548, 804583]]
# Number 793271 is in more than one sequence:  [[793271, 803937], [803179, 793271, 813736, 804710], [793271, 803938, 804242, 809631]]
# Number 808021 is in more than one sequence:  [[808021, 804725], [801979, 808021, 813406, 809526, 810081]]
# Number 793006 is in more than one sequence:  [[793006, 793223, 800473, 803930], [793006, 803626, 812029, 808940, 804057, 804850]]
# Number 800473 is in more than one sequence:  [[793006, 793223, 800473, 803930], [800473, 809686], [800473, 803831], [800473, 805913], [800473, 806491, 808324, 804939], [800473, 804235, 805412, 810364, 811681]]
# Number 808806 is in more than one sequence:  [[762964, 761995, 778157, 773304, 774865, 774648, 772780, 782281, 787176, 797386, 797828, 798606, 807169, 808806, 813274], [808806, 805415], [808806, 807170, 811808], [808806, 811774, 803935, 804017, 809543]]
# Number 795289 is in more than one sequence:  [[795289, 802758, 813721], [795289, 800990, 804966, 810436, 808131, 810115], [794971, 801183, 802632, 795289, 800203, 810333, 811876, 805539, 809569, 813497, 817150, 824153, 823253, 814824]]
# Number 811802 is in more than one sequence:  [[811802, 809881], [797729, 794502, 800213, 811802, 809724, 808521], [811802, 811223, 804454, 808252, 807548, 817388, 814858]]
# Number 802817 is in more than one sequence:  [[802817, 809437, 804193], [768433, 768143, 776487, 773507, 778022, 788093, 785755, 782886, 788644, 794424, 797109, 802817, 808939, 804452, 810639]]
# Number 806721 is in more than one sequence:  [[806721, 808152], [793192, 793987, 806721, 810006, 805021]]
# Number 799900 is in more than one sequence:  [[799900, 806792], [799900, 809458], [799900, 810031], [799900, 807116]]
# Number 813008 is in more than one sequence:  [[805720, 813008, 805234], [813008, 805937, 810660, 810623]]
# Number 800284 is in more than one sequence:  [[795716, 800284, 808993], [800284, 805662, 804383, 804990, 808620]]
# Number 799901 is in more than one sequence:  [[799901, 803373, 811366, 812907], [799901, 799302, 805163, 806096, 810879, 807124], [799901, 798563, 812412, 804130, 810479]]
# Number 802258 is in more than one sequence:  [[802258, 810078], [793748, 794317, 800491, 802258, 813815, 810079], [802258, 810449, 804212, 814671], [802258, 808541, 809525, 805952, 806575, 817786]]
# Number 800420 is in more than one sequence:  [[787234, 790473, 783093, 798721, 801357, 801960, 800420, 805949], [800420, 810863], [800420, 804470, 808395, 807019, 814429], [800420, 813503, 809913, 818619, 822263], [800420, 813968, 806987, 819336]]
# Number 804358 is in more than one sequence:  [[804358, 804359], [785799, 789164, 785579, 797111, 793747, 803054, 804358, 804702, 804853, 808937, 805997]]
# Number 810617 is in more than one sequence:  [[810617, 809424], [810617, 806778], [801463, 810617, 808549, 806948]]
# Number 812029 is in more than one sequence:  [[812029, 809534], [812029, 803832], [793006, 803626, 812029, 808940, 804057, 804850]]
# Number 805397 is in more than one sequence:  [[805397, 808671], [805397, 813012, 806153, 807447], [800347, 813954, 805397, 814135, 806757, 817234, 830518, 838658]]
# Number 800768 is in more than one sequence:  [[797568, 800768, 809843], [800768, 813110], [800768, 809710]]
# Number 793719 is in more than one sequence:  [[793719, 795612, 800730, 807240], [801401, 793676, 793719, 794055, 804889], [793719, 801618, 805407, 812172, 808180], [793719, 802960, 812059, 812448, 812357, 804661]]
# Number 804548 is in more than one sequence:  [[803631, 801773, 804548, 810897, 805617], [804548, 811999, 806722, 809814, 807037]]
# Number 801838 is in more than one sequence:  [[801838, 805315], [801838, 809682, 807738]]
# Number 803571 is in more than one sequence:  [[773508, 775374, 787303, 783368, 795596, 803571, 807755, 807422], [803571, 805055, 812302, 814328], [803571, 814167, 805981, 813601, 808382, 812875, 806114]]
# Number 793748 is in more than one sequence:  [[793748, 796376, 808490, 812518], [793748, 794317, 800491, 802258, 813815, 810079], [796461, 793748, 799754, 795613, 805647, 811145, 807883], [793748, 800939, 810359, 806833, 806040, 815657]]
# Number 809771 is in more than one sequence:  [[809771, 804234], [809771, 808036]]
# Number 805538 is in more than one sequence:  [[805538, 808276], [805538, 805220, 805550], [782575, 783064, 799294, 794968, 793558, 802648, 801201, 808205, 805538, 804802, 808590, 806905, 809125, 814781, 814663, 822893, 818339, 815465]]
# Number 812544 is in more than one sequence:  [[812544, 809059], [812544, 809223, 805082, 804750], [812544, 810835, 806047, 805682], [812544, 807955, 812509, 809436]]
# Number 801108 is in more than one sequence:  [[801352, 797070, 795887, 802505, 801108, 812263, 805556], [801108, 807280, 812030, 807697, 807637, 811182, 807951], [801108, 804918, 804601, 810909, 814864]]
# Number 809380 is in more than one sequence:  [[802220, 802607, 797726, 803094, 809380, 807689], [809380, 806902], [809380, 805178, 811965], [809380, 809150, 807597, 808703, 812670], [809380, 811708, 804198, 804199, 817766]]
# Number 809880 is in more than one sequence:  [[800419, 809880, 810809, 810334], [809880, 807696, 806816]]
# Number 812360 is in more than one sequence:  [[812360, 812873], [812360, 811803], [812360, 807977], [812360, 812272], [812360, 810533], [812360, 807800], [797298, 799620, 812360, 807804, 809345, 813532, 809300], [812360, 813125, 813126, 812510, 816554, 820271, 815933]]
# Number 804932 is in more than one sequence:  [[792090, 802092, 804932, 809751], [804932, 812676, 812677, 809003, 814803, 818375]]
# Number 798842 is in more than one sequence:  [[798842, 801978, 793211, 801083, 809909, 807072], [779375, 791557, 784064, 784324, 791034, 802347, 802789, 798842, 798793, 801447, 811686, 806347, 821165, 819981, 826273, 827859]]
# Number 804211 is in more than one sequence:  [[804211, 804845], [800932, 793561, 794844, 802995, 804211, 810302, 805235, 804033, 806543, 805227]]
# Number 811999 is in more than one sequence:  [[811999, 807373], [811999, 804755], [804548, 811999, 806722, 809814, 807037], [811999, 810975, 805159, 811791, 821082, 819459, 816851, 819602, 818507]]
# Number 809948 is in more than one sequence:  [[793504, 809948, 805848], [809948, 805040]]
# Number 797498 is in more than one sequence:  [[797498, 812376], [797498, 808932], [797498, 811895], [795715, 797498, 807614, 805569], [797498, 807031, 815822], [797498, 805700, 806014, 820479, 822699, 821332, 828279, 829917, 825648, 838052]]
# Number 804586 is in more than one sequence:  [[777441, 784692, 789356, 789640, 785863, 783303, 793244, 799322, 798744, 793525, 793940, 804586, 812131], [804586, 813594, 806383]]
# Number 797948 is in more than one sequence:  [[797948, 804600, 813995], [795091, 797948, 805266, 809284, 813662, 811647, 821157, 821821, 814867, 815765, 819017, 821020, 832117]]
# Number 806033 is in more than one sequence:  [[797653, 806033, 805964], [806033, 808415, 813364]]
# Number 804020 is in more than one sequence:  [[804020, 807737], [798809, 795411, 802434, 794122, 813298, 804020, 809365, 811584], [804020, 808247, 804218], [804020, 810363, 813425]]
# Number 812658 is in more than one sequence:  [[812658, 805439], [794930, 802900, 794499, 812658, 810171, 810172, 807512, 817718, 817972]]
# Number 805980 is in more than one sequence:  [[805980, 811928, 812103], [795828, 805980, 808690, 813073, 811367, 804908], [805980, 812935, 812296, 808901, 805784], [805980, 803927, 804459, 803987, 810584]]
# Number 794618 is in more than one sequence:  [[783803, 794618, 805267], [794618, 811037, 807308]]
# Number 805822 is in more than one sequence:  [[805822, 814001], [805822, 804109, 805298], [805822, 805963, 806227], [805981, 805822, 807692, 807606, 804476, 811321], [805822, 804911, 807330, 808693, 823841, 818119, 817412]]
# Number 812017 is in more than one sequence:  [[801415, 812017, 803877], [812017, 805528, 808912, 804023, 808850]]
# Number 809493 is in more than one sequence:  [[809493, 812702], [809493, 811073, 807312], [809493, 804352, 813722]]
# Number 810323 is in more than one sequence:  [[810323, 804274], [810139, 810323, 804747, 808181]]
# Number 797048 is in more than one sequence:  [[795005, 795810, 799572, 801759, 797048, 794721, 810867, 812898], [797048, 801073, 806962, 809941, 809878, 808270, 814368, 814765]]
# Number 805981 is in more than one sequence:  [[805981, 807647, 807596], [805981, 809513, 809366], [805981, 805822, 807692, 807606, 804476, 811321], [803571, 814167, 805981, 813601, 808382, 812875, 806114]]
# Number 806467 is in more than one sequence:  [[806467, 804007], [794328, 794529, 806467, 808210, 807838, 813888], [806467, 804826, 814386, 809256, 822439]]
# Number 799705 is in more than one sequence:  [[799705, 807041, 803843], [782852, 784197, 799705, 807293, 809568, 807389, 806237]]
# Number 807041 is in more than one sequence:  [[799705, 807041, 803843], [807041, 808271, 805670], [807041, 810841, 807374, 809617, 811715, 823540, 823044], [807041, 810374, 804348, 804434, 813402, 815802, 814915, 817622, 822080]]
# Number 793013 is in more than one sequence:  [[793013, 804474, 807445, 811915], [798205, 797858, 796883, 793013, 797508, 807930, 807073, 812693, 819489]]
# Number 808541 is in more than one sequence:  [[808541, 810810], [802258, 808541, 809525, 805952, 806575, 817786]]
# Number 805831 is in more than one sequence:  [[805831, 810474], [805831, 805832, 808764, 807622]]
# Number 804116 is in more than one sequence:  [[794131, 804116, 804320], [804116, 808319, 804086]]
# Number 814168 is in more than one sequence:  [[802721, 794818, 803835, 806906, 814168, 811185, 805783], [814168, 809852, 804989, 808518, 803939, 812122]]
# Number 814384 is in more than one sequence:  [[814384, 814362], [809960, 814384, 805295, 809446, 810776], [814384, 814385, 806950, 805049, 808301, 819629]]
# Number 807299 is in more than one sequence:  [[807299, 808583, 807831], [792715, 784093, 798382, 793083, 797575, 793737, 807748, 807299, 809210, 804587, 807796], [807299, 804246, 807636, 811662, 807233], [807299, 807300, 807506, 818003]]
# Number 808583 is in more than one sequence:  [[807299, 808583, 807831], [808583, 811370]]
# Number 800268 is in more than one sequence:  [[797476, 800268, 802101, 800633, 811110, 809141], [800268, 794669, 794955, 806667, 809095, 807432]]
# Number 803910 is in more than one sequence:  [[801184, 799360, 809048, 803910, 813213], [803910, 809632, 804009, 810279]]
# Number 807696 is in more than one sequence:  [[809880, 807696, 806816], [807696, 807311, 813074, 803830]]
# Number 789176 is in more than one sequence:  [[789176, 801297, 796747, 812885, 812264], [788305, 786141, 784079, 789176, 794084, 813955, 810077, 818982, 815632]]
# Number 795006 is in more than one sequence:  [[795006, 796570, 804027], [795006, 802723, 811575, 812822, 812079]]
# Number 812477 is in more than one sequence:  [[812477, 810590], [812477, 808174, 810583, 804726]]
# Number 796813 is in more than one sequence:  [[796813, 806368], [798998, 796813, 805736, 814921], [796813, 807679, 821830, 821152, 820464, 820465, 826003, 824264, 826193, 830632]]
# Number 797158 is in more than one sequence:  [[797158, 811776], [797158, 807868], [797158, 813328, 809297, 805394], [799919, 794284, 797158, 804277, 823200, 819876, 819877]]
# Number 814350 is in more than one sequence:  [[814350, 809669], [800186, 799641, 793043, 814350, 814351, 807508, 809576, 811418]]
# Number 794264 is in more than one sequence:  [[796804, 794264, 808017], [794264, 808882], [794264, 813748], [794264, 813250, 808849, 809731, 804892, 819328, 824069]]
# Number 803970 is in more than one sequence:  [[793296, 803282, 794870, 809117, 803970, 812729], [803970, 811416, 805897, 809350, 806413, 823507]]
# Number 799617 is in more than one sequence:  [[796089, 799617, 798475, 793954, 813971], [799617, 799573, 794345, 800119, 812535, 811078]]
# Number 803836 is in more than one sequence:  [[803836, 804200, 809402], [801415, 803836, 810476, 806652, 812519, 813286, 805245, 816974, 820017, 815530]]
# Number 807886 is in more than one sequence:  [[793195, 793123, 807886, 813113, 804123], [807886, 812256, 809952]]
# Number 813113 is in more than one sequence:  [[793195, 793123, 807886, 813113, 804123], [813113, 805158]]
# Number 802988 is in more than one sequence:  [[783406, 783553, 786834, 793946, 795512, 793296, 793836, 802988, 798708, 806425, 814169], [802988, 813600, 812696, 810911, 805988, 812233, 815535]]
# Number 810596 is in more than one sequence:  [[810596, 805543], [810595, 810596, 807648, 813260, 817688]]
# Number 810841 is in more than one sequence:  [[810841, 811401], [807041, 810841, 807374, 809617, 811715, 823540, 823044]]
# Number 807675 is in more than one sequence:  [[807675, 803857], [798063, 800292, 796496, 807675, 814355, 810443]]
# Number 810333 is in more than one sequence:  [[810333, 812051, 809995], [794971, 801183, 802632, 795289, 800203, 810333, 811876, 805539, 809569, 813497, 817150, 824153, 823253, 814824]]
# Number 808453 is in more than one sequence:  [[808453, 811280], [805294, 808453, 809951, 805060, 809589, 823718, 819128]]
# Number 797951 is in more than one sequence:  [[800016, 797951, 813667], [797951, 806572, 810342]]
# Number 811208 is in more than one sequence:  [[811208, 814354], [811208, 806680], [811208, 811081, 810890], [811208, 813644, 806435], [811208, 812730, 805891, 809579]]
# Number 810850 is in more than one sequence:  [[799620, 807478, 810850, 807052], [810850, 807229]]
# Number 798514 is in more than one sequence:  [[798514, 812508, 807756], [798514, 806525, 809737, 810390, 805448], [793005, 798514, 811692, 808550, 810438, 815218, 819196, 822690, 823405, 814966]]
# Number 804568 is in more than one sequence:  [[804568, 808626], [804568, 812303], [804568, 811119, 810728, 805236]]
# Number 807650 is in more than one sequence:  [[807650, 805613], [795951, 808989, 807650, 810645, 813812]]
# Number 793635 is in more than one sequence:  [[793635, 809224], [783082, 793635, 807464, 813195, 809404, 821312]]
# Number 806572 is in more than one sequence:  [[797951, 806572, 810342], [806572, 807670, 806573]]
# Number 814183 is in more than one sequence:  [[795803, 803208, 793354, 793929, 799210, 814183, 804021, 810880], [814183, 808241, 804247, 803827, 818034]]
# Number 804021 is in more than one sequence:  [[795803, 803208, 793354, 793929, 799210, 814183, 804021, 810880], [804021, 809853], [804021, 806097, 806452, 809707, 809130], [804021, 806238, 810462, 814513], [804021, 804465, 806738, 812226, 804284, 818589], [804021, 803928, 808793, 818687, 829977, 831764, 829591, 824384]]
# Number 806142 is in more than one sequence:  [[806142, 807514], [813365, 806142, 803898, 804698]]
# Number 813528 is in more than one sequence:  [[813528, 808657], [813528, 808514], [813528, 804008], [813528, 808621, 814308], [813528, 812937, 808873, 806967], [813528, 803853, 805464, 808499], [813528, 811629, 809696, 806059]]
# Number 793029 is in more than one sequence:  [[782804, 788562, 796642, 799034, 799513, 793029, 810292, 804703], [793029, 806850, 805924, 812304, 820788, 816215, 820641, 821334, 816000], [793029, 806758, 814796, 821720, 814774, 814912, 830392, 829541, 825417]]
# Number 810292 is in more than one sequence:  [[782804, 788562, 796642, 799034, 799513, 793029, 810292, 804703], [810292, 804089, 807956], [810292, 810293, 811398, 810444, 803918, 815877, 817284, 815102]]
# Number 793192 is in more than one sequence:  [[797032, 793192, 795676, 804881, 811359], [793192, 793987, 806721, 810006, 805021], [793192, 798551, 810494, 808628, 807192, 812300], [793192, 796708, 806048, 805390, 805595, 805027, 812881, 815271]]
# Number 797882 is in more than one sequence:  [[779322, 775721, 775722, 774017, 790601, 782746, 803175, 801751, 797882, 793056, 805666, 811295, 806155], [797882, 804177, 807903, 812276, 809110, 804828, 814804, 818338, 823318]]
# Number 805306 is in more than one sequence:  [[805306, 807430, 807431], [803721, 799101, 805942, 805306, 808618, 807423, 814323, 816244, 816245]]
# Number 807670 is in more than one sequence:  [[806572, 807670, 806573], [807670, 813926], [807670, 811509], [807670, 804210], [807670, 813376, 815572, 824159], [807670, 806535, 817545, 817800, 817710, 822281], [807670, 807008, 814417, 820595, 823942, 815170, 819134, 831214, 827241]]
# Number 797506 is in more than one sequence:  [[797506, 809235, 813065, 804400], [772275, 782217, 774608, 787345, 787396, 793963, 801252, 797506, 813112, 813771, 804862, 811334, 803988, 816336, 817971]]
# Number 814361 is in more than one sequence:  [[808881, 814361, 806045, 804478], [814361, 810926, 809195, 811585, 818180, 821917, 822348]]
# Number 807579 is in more than one sequence:  [[807579, 809828, 807915, 807745, 810201], [794296, 795637, 801098, 807579, 806459, 805906, 806003]]
# Number 807915 is in more than one sequence:  [[807579, 809828, 807915, 807745, 810201], [807915, 807176, 805162], [807915, 808412, 810662, 804588], [807915, 807142, 804013, 813265], [807915, 807866, 809180, 804617, 806220], [807915, 806223, 813066, 810826, 818118], [807915, 811296, 804046, 805392, 811809, 823845, 814972, 822318]]
# Number 807745 is in more than one sequence:  [[807579, 809828, 807915, 807745, 810201], [807745, 804201, 806083, 803837, 803838, 820376, 822887, 815732]]
# Number 810374 is in more than one sequence:  [[810374, 811114], [810374, 805667, 805368, 805293], [807041, 810374, 804348, 804434, 813402, 815802, 814915, 817622, 822080]]
# Number 813328 is in more than one sequence:  [[797158, 813328, 809297, 805394], [813328, 811933, 821738]]
# Number 809297 is in more than one sequence:  [[797158, 813328, 809297, 805394], [809297, 809298, 818842, 819567, 819066, 826506, 826507]]
# Number 814385 is in more than one sequence:  [[814385, 808768], [814384, 814385, 806950, 805049, 808301, 819629], [814385, 811209, 811597, 810296, 820269, 824158, 817982], [814385, 810571, 807808, 809989, 806797, 817475, 814503], [814385, 808083, 810563, 823934, 815523, 814993]]
# Number 807585 is in more than one sequence:  [[807585, 812878, 807607], [797074, 806892, 807585, 809076, 809654]]
# Number 808174 is in more than one sequence:  [[808174, 811775], [812477, 808174, 810583, 804726]]
# Number 807456 is in more than one sequence:  [[807456, 805985], [807456, 813869, 805373, 812081]]
# Number 813700 is in more than one sequence:  [[813700, 810489], [813700, 812382, 803815, 803911], [810139, 813700, 804738, 810502, 804649, 814416, 819980]]
# Number 809094 is in more than one sequence:  [[809094, 812691, 808320], [809094, 813630, 811787], [810877, 809209, 809094, 812009, 805578], [809094, 807990, 813479, 806681], [809094, 804016, 812229, 810008, 822007, 819143]]
# Number 813643 is in more than one sequence:  [[799839, 793165, 812397, 813643, 812494, 807397], [813643, 811405, 809813], [813643, 804099, 810588], [813643, 805119, 813587, 808883, 803949, 814504, 815631], [813643, 814333, 805375, 806239, 817689, 814991, 815321, 821526]]
# Number 809566 is in more than one sequence:  [[793091, 801049, 813011, 809566, 811541, 804314], [809566, 813808, 805126]]
# Number 810436 is in more than one sequence:  [[810436, 804433], [795289, 800990, 804966, 810436, 808131, 810115], [810436, 810057, 812327, 821997, 821754, 816854, 823404], [810436, 804962, 804963, 805174, 817124, 816191, 823833, 826716, 824746, 827724]]
# Number 800597 is in more than one sequence:  [[800597, 808020, 805544], [793301, 800597, 808702, 805940, 808994, 811134], [800597, 808375, 807171, 810496, 814823, 817292, 815221]]
# Number 805849 is in more than one sequence:  [[793208, 798967, 796298, 808408, 805849, 804901], [805849, 805657, 808022, 813595, 810490]]
# Number 806795 is in more than one sequence:  [[806795, 804425, 809025], [783862, 794404, 799191, 809616, 806795, 803958, 807487, 806122, 817291, 815505]]
# Number 803600 is in more than one sequence:  [[800225, 802229, 803600, 804539], [803600, 813091], [803600, 805495], [803600, 804024, 804025], [803600, 811635, 817632, 821414, 816304]]
# Number 805037 is in more than one sequence:  [[802721, 799266, 801041, 800281, 805037, 805221], [805037, 812137, 807479, 813299, 817238, 814404, 816844]]
# Number 810911 is in more than one sequence:  [[810911, 808214], [802988, 813600, 812696, 810911, 805988, 812233, 815535]]
# Number 808247 is in more than one sequence:  [[804020, 808247, 804218], [808247, 808570, 811171], [808247, 808207, 812330], [808247, 809192, 822862, 822863, 814589]]
# Number 808690 is in more than one sequence:  [[808690, 813623, 806617], [795828, 805980, 808690, 813073, 811367, 804908]]
# Number 814333 is in more than one sequence:  [[814333, 812445], [813643, 814333, 805375, 806239, 817689, 814991, 815321, 821526]]
# Number 807996 is in more than one sequence:  [[807996, 814353, 812283, 806656], [795044, 795790, 803368, 807700, 807996, 805334, 806718, 805299]]
# Number 814353 is in more than one sequence:  [[807996, 814353, 812283, 806656], [814353, 809575, 808263], [814353, 806904, 805226, 810186, 817524, 820401, 821891]]
# Number 809591 is in more than one sequence:  [[809591, 811615, 812260, 808277], [787395, 788873, 802922, 796991, 800706, 800707, 802749, 807152, 809591, 808691, 804412, 805493, 805506, 817410, 819065, 821823, 820555, 823072]]
# Number 810171 is in more than one sequence:  [[810171, 807887], [810171, 803796, 806659], [810171, 807348, 808828], [810171, 809299, 805416], [794930, 802900, 794499, 812658, 810171, 810172, 807512, 817718, 817972]]
# Number 808940 is in more than one sequence:  [[793006, 803626, 812029, 808940, 804057, 804850], [808940, 812361, 804912, 810080]]
# Number 804057 is in more than one sequence:  [[793006, 803626, 812029, 808940, 804057, 804850], [804057, 805734, 810341, 811184, 804053]]
# Number 806899 is in more than one sequence:  [[806899, 809695], [794036, 804287, 806899, 807746, 812371, 810322, 819893, 822658, 820900]]
# Number 811074 is in more than one sequence:  [[811074, 808827], [809343, 803829, 811074, 807125, 807805, 808248, 810376, 808561], [811074, 806796, 808354, 822395], [811074, 806600, 811684, 812537, 819041]]
# Number 805082 is in more than one sequence:  [[812544, 809223, 805082, 804750], [805082, 807065, 805283, 805124, 805284], [805082, 805701, 808321]]
# Number 802807 is in more than one sequence:  [[802807, 804524], [796346, 794754, 795244, 802807, 810430, 815176, 822903]]
# Number 811180 is in more than one sequence:  [[811180, 812060], [809435, 811180, 810303, 809163], [811180, 806801, 812741, 822785, 819634]]
# Number 803871 is in more than one sequence:  [[797672, 798243, 798290, 803871, 806838, 809877], [803871, 804751, 804576, 807334]]
# Number 802531 is in more than one sequence:  [[802531, 794781, 795633, 805785, 803872], [801978, 802531, 794613, 796342, 811113, 804907, 803959, 807591]]
# Number 804235 is in more than one sequence:  [[804235, 807749], [800473, 804235, 805412, 810364, 811681]]
# Number 807746 is in more than one sequence:  [[807746, 804124], [807746, 807547], [807746, 807103, 808477], [807746, 813719, 810868], [794036, 804287, 806899, 807746, 812371, 810322, 819893, 822658, 820900]]
# Number 805057 is in more than one sequence:  [[805057, 811118], [805057, 809255, 810562, 807025, 806660, 815328, 815719, 823650], [796790, 792978, 802471, 811407, 805057, 811257, 814019, 812407, 818485, 816531, 823016, 821703]]
# Number 810877 is in more than one sequence:  [[784303, 800404, 802697, 810877, 809485, 809940], [810877, 809209, 809094, 812009, 805578]]
# Number 809485 is in more than one sequence:  [[784303, 800404, 802697, 810877, 809485, 809940], [809485, 810710], [809485, 805786, 813813], [809485, 808448, 817508, 817122, 818540, 820768], [809485, 805190, 804226, 822674, 822300, 820554, 818411, 823363, 831132, 826190]]
# Number 807692 is in more than one sequence:  [[807692, 812883, 812886, 807255], [805981, 805822, 807692, 807606, 804476, 811321]]
# Number 812886 is in more than one sequence:  [[807692, 812883, 812886, 807255], [812886, 812173], [812886, 810330], [812886, 808419, 805214], [812886, 812619, 807126], [812886, 804388, 808591, 814994]]
# Number 805852 is in more than one sequence:  [[805852, 805853, 809126], [805852, 804045, 803947, 807333, 804014, 804987]]
# Number 800490 is in more than one sequence:  [[800490, 793336, 813513], [802385, 800490, 802676, 797814, 805748, 805048, 811279]]
# Number 810477 is in more than one sequence:  [[810477, 805129], [810477, 805353]]
# Number 797156 is in more than one sequence:  [[797156, 807877, 811132, 812265], [797156, 809586, 809381, 812437], [792118, 788030, 799084, 794889, 797156, 807842, 807843, 813886, 808942]]
# Number 811132 is in more than one sequence:  [[797156, 807877, 811132, 812265], [811132, 810632], [811132, 805824], [811132, 811133, 812432], [811132, 804307, 807532, 806544], [811132, 813529, 811281, 818481]]
# Number 809996 is in more than one sequence:  [[809996, 809949, 810007], [803349, 795358, 795728, 805122, 809996, 808409, 808242, 811905, 816593, 823263, 817448, 820910, 817711, 817215, 824295]]
# Number 809949 is in more than one sequence:  [[809996, 809949, 810007], [809949, 807414, 810034]]
# Number 813897 is in more than one sequence:  [[813897, 803917], [813897, 804230, 804846], [813160, 804282, 813897, 806046, 806249]]
# Number 793737 is in more than one sequence:  [[792715, 784093, 798382, 793083, 797575, 793737, 807748, 807299, 809210, 804587, 807796], [793737, 805294, 807997, 806531]]
# Number 805235 is in more than one sequence:  [[805235, 808941], [805235, 804827, 809544], [805235, 805120, 806091, 811309], [805235, 812031, 809463, 811675], [800932, 793561, 794844, 802995, 804211, 810302, 805235, 804033, 806543, 805227]]
# Number 809575 is in more than one sequence:  [[814353, 809575, 808263], [809575, 806306]]
# Number 807825 is in more than one sequence:  [[783039, 784482, 795399, 800815, 793179, 799848, 801697, 807825, 804692, 807419, 808899], [807825, 811716, 806960, 804920]]
# Number 804692 is in more than one sequence:  [[783039, 784482, 795399, 800815, 793179, 799848, 801697, 807825, 804692, 807419, 808899], [804692, 808435, 807724, 809035]]
# Number 810662 is in more than one sequence:  [[807915, 808412, 810662, 804588], [810662, 810707], [810662, 813985], [810662, 812887, 812888], [810662, 811417, 804087, 808515, 811704], [810662, 809890, 811469, 809618, 821490, 815270], [810662, 811262, 812572, 814745, 821625]]
# Number 804013 is in more than one sequence:  [[807915, 807142, 804013, 813265], [804013, 806002, 819573, 819815]]
# Number 805458 is in more than one sequence:  [[805458, 804117], [798416, 803807, 805458, 809231, 813093, 804203, 814608, 819136]]
# Number 806194 is in more than one sequence:  [[806194, 810277], [806194, 807813, 809154, 816775, 822814, 816220]]
# Number 805013 is in more than one sequence:  [[805013, 813057, 813990], [805013, 808454, 809959]]
# Number 799122 is in more than one sequence:  [[799122, 813173, 814306], [795902, 799122, 804291, 818073]]
# Number 813173 is in more than one sequence:  [[799122, 813173, 814306], [813173, 804423], [813173, 805043, 817152, 814500], [813173, 813174, 823809]]
# Number 809586 is in more than one sequence:  [[809586, 811712, 811713], [797156, 809586, 809381, 812437]]
# Number 809446 is in more than one sequence:  [[809960, 814384, 805295, 809446, 810776], [809446, 812495, 806961, 817822, 822913, 821998]]
# Number 812605 is in more than one sequence:  [[812605, 812606], [812605, 807801, 809738], [805056, 809124, 812605, 810906, 817208], [812605, 810433, 806408, 817300, 819730, 815764, 823800]]
# Number 809213 is in more than one sequence:  [[801836, 795973, 795787, 813303, 811985, 809213, 807249], [809213, 810127]]
# Number 807235 is in more than one sequence:  [[807234, 807235, 808393, 814130], [807235, 809587, 810927, 809369]]
# Number 809752 is in more than one sequence:  [[809752, 807457], [809752, 809988, 811693], [809752, 807114, 808376, 808829, 804480], [802385, 802592, 800684, 804688, 809752, 805580, 808027, 816006, 818682]]
# Number 807125 is in more than one sequence:  [[807125, 813631], [809343, 803829, 811074, 807125, 807805, 808248, 810376, 808561]]
# Number 811340 is in more than one sequence:  [[811340, 806534, 805083], [811340, 812234, 808915, 805986]]
# Number 805335 is in more than one sequence:  [[801463, 813526, 811929, 805335, 805336], [805335, 808295]]
# Number 811555 is in more than one sequence:  [[811555, 813590], [811555, 805108, 805991], [811555, 809236, 807493], [811555, 809927, 805851, 814903, 821718]]
# Number 793457 is in more than one sequence:  [[793335, 796980, 793457, 814150, 809153], [793457, 804035, 812692, 804263, 804219], [793457, 813607, 806627, 817453, 817544, 820988], [793457, 806391, 808044, 806646, 819670, 815407], [793457, 808089, 803809, 814507]]
# Number 803796 is in more than one sequence:  [[810171, 803796, 806659], [803796, 809058]]
# Number 804268 is in more than one sequence:  [[794930, 793197, 795514, 804268, 806212, 812418], [804268, 806310, 805317, 815363, 818987]]
# Number 805294 is in more than one sequence:  [[793737, 805294, 807997, 806531], [805294, 808453, 809951, 805060, 809589, 823718, 819128]]
# Number 807997 is in more than one sequence:  [[793737, 805294, 807997, 806531], [807997, 804460], [807997, 804205], [807997, 807998, 812018, 814364], [807997, 806162, 819769]]
# Number 812137 is in more than one sequence:  [[812137, 811341], [812137, 805249], [805037, 812137, 807479, 813299, 817238, 814404, 816844]]
# Number 808485 is in more than one sequence:  [[808881, 808485, 805625], [808485, 809993, 815081, 815656, 821264, 817525, 816709]]
# Number 807676 is in more than one sequence:  [[801084, 793093, 807676, 810540], [807676, 810278, 809816, 819480, 821019]]
# Number 796077 is in more than one sequence:  [[796077, 813859, 812121, 806156], [801444, 802069, 796077, 805467, 813847, 805041]]
# Number 810820 is in more than one sequence:  [[805526, 812569, 810820, 806143], [810820, 809588]]
# Number 813092 is in more than one sequence:  [[813092, 810202], [813092, 805944], [813092, 804036, 804696]]
# Number 800959 is in more than one sequence:  [[800959, 808647], [800959, 812944, 811277]]
# Number 809345 is in more than one sequence:  [[809345, 806779], [797298, 799620, 812360, 807804, 809345, 813532, 809300]]
# Number 809930 is in more than one sequence:  [[809930, 813816], [809930, 814034], [809930, 810625, 805614], [809930, 809077, 812090], [806305, 809930, 812744, 815245, 830607, 829748]]
# Number 799804 is in more than one sequence:  [[799804, 804382], [784093, 798281, 800752, 795972, 801428, 799804, 814210, 804333]]
# Number 812944 is in more than one sequence:  [[800959, 812944, 811277], [812944, 804813], [812944, 809505], [812944, 807123, 815408], [812944, 804050, 814872, 817918]]
# Number 814210 is in more than one sequence:  [[784093, 798281, 800752, 795972, 801428, 799804, 814210, 804333], [814210, 811258], [814210, 804550], [814210, 807093], [814210, 814211]]
# Number 813009 is in more than one sequence:  [[813009, 803844, 813334], [791916, 789403, 783662, 791164, 798815, 800418, 795452, 794398, 802140, 809435, 813009, 811181, 813010]]
# Number 803844 is in more than one sequence:  [[813009, 803844, 813334], [803844, 806037, 804360, 819844, 819036, 818130]]
# Number 807389 is in more than one sequence:  [[782852, 784197, 799705, 807293, 809568, 807389, 806237], [807389, 811844]]
# Number 806460 is in more than one sequence:  [[783862, 798848, 808019, 813495, 806460, 803882], [806460, 812277, 809524, 823561, 820392, 817865]]
# Number 806796 is in more than one sequence:  [[806796, 803819], [806796, 806131], [811074, 806796, 808354, 822395]]
# Number 809650 is in more than one sequence:  [[809650, 811996, 808158], [809650, 811709, 806492, 824029], [809650, 809885, 820282, 825246, 828734, 831344, 830182, 824861, 828588]]
# Number 811996 is in more than one sequence:  [[809650, 811996, 808158], [811996, 813145], [811996, 808288], [811996, 808669], [811996, 806869, 805160, 822927], [811996, 809454, 811409, 814776, 817151, 823835, 819789], [811996, 813198, 808551, 815606, 817833, 817732, 817286, 826222, 831335]]
# Number 813050 is in more than one sequence:  [[813050, 808630], [813050, 812399, 804353]]
# Number 804862 is in more than one sequence:  [[804862, 804610, 804992], [804862, 809542, 805697, 809879], [804862, 807916, 808396, 815753], [772275, 782217, 774608, 787345, 787396, 793963, 801252, 797506, 813112, 813771, 804862, 811334, 803988, 816336, 817971], [804862, 804863, 809931, 822572, 821247, 819674, 816930, 817841, 830475, 826389, 830399]]
# Number 803805 is in more than one sequence:  [[791498, 800143, 802395, 803805, 805053], [803805, 813075]]
# Number 804806 is in more than one sequence:  [[804806, 809844, 812982], [803123, 795174, 804183, 804806, 808377, 804118, 804119]]
# Number 806172 is in more than one sequence:  [[806172, 807778], [806172, 809120, 808791, 814977, 819559], [806172, 812143, 816883, 816361]]
# Number 806188 is in more than one sequence:  [[806188, 812880], [806188, 812008, 804700, 812001, 820451], [801289, 802869, 806188, 811556, 819090, 814739, 814559]]
# Number 807313 is in more than one sequence:  [[807313, 814304], [807313, 807625, 810128], [804988, 809592, 807313, 806042, 807783]]
# Number 809577 is in more than one sequence:  [[809577, 804058], [809577, 813765, 809111]]
# Number 805056 is in more than one sequence:  [[791458, 798543, 797299, 809516, 805056, 805671, 813237, 808225], [805056, 809124, 812605, 810906, 817208]]
# Number 804853 is in more than one sequence:  [[785799, 789164, 785579, 797111, 793747, 803054, 804358, 804702, 804853, 808937, 805997], [804853, 805990, 810546, 804315, 804685, 818739, 815182]]
# ...
# Number 936474 is in more than one sequence:  [[920836, 919459, 929156, 928712, 930357, 936474, 941579], [936474, 939575], [936474, 942371]]
# Number 935139 is in more than one sequence:  [[935139, 944220], [935139, 937328], [935139, 935140], [924861, 915920, 930821, 926002, 928161, 932009, 925655, 929258, 933892, 935139, 944337, 937500]]
# Number 934782 is in more than one sequence:  [[934782, 939098], [934782, 943765], [934782, 936469, 941855], [933526, 934015, 928984, 934782, 935475, 940801]]
# Number 943070 is in more than one sequence:  [[943070, 939523], [926499, 931816, 943070, 936606, 936343]]
# Number 943422 is in more than one sequence:  [[939947, 943422, 942155, 943003], [943422, 944447, 939603], [943422, 942840, 934614], [943422, 938366, 934987], [943422, 943423, 935179]]
# Number 926383 is in more than one sequence:  [[931456, 928032, 926383, 937273, 940364], [926383, 940341, 944134]]
# Number 935978 is in more than one sequence:  [[935978, 940272], [926467, 927993, 927120, 927334, 927531, 929782, 936794, 935978, 936782, 942731]]
# Number 944447 is in more than one sequence:  [[943422, 944447, 939603], [944447, 939591]]
# Number 929782 is in more than one sequence:  [[929782, 935312, 936423], [926467, 927993, 927120, 927334, 927531, 929782, 936794, 935978, 936782, 942731]]
# Number 938494 is in more than one sequence:  [[933914, 938494, 939895], [938494, 940474], [938494, 941635, 941636, 934706]]
# Number 931302 is in more than one sequence:  [[931302, 939149, 943965], [931302, 939967, 938188, 935952], [931302, 943024, 940791]]
# Number 926929 is in more than one sequence:  [[925051, 926929, 936265], [926929, 941410], [926929, 943187], [926929, 941437], [926929, 944408]]
# Number 938497 is in more than one sequence:  [[917220, 923283, 924273, 920715, 924211, 923803, 926122, 938497, 937339], [938497, 936628], [938497, 939392, 940729], [938497, 935971, 939269]]
# Number 936309 is in more than one sequence:  [[907302, 907222, 921956, 917152, 920682, 928827, 932211, 929344, 932287, 925475, 925094, 933372, 936309, 934390], [936309, 938343], [936309, 934833]]
# Number 938180 is in more than one sequence:  [[938180, 935948, 944648], [938180, 942491, 942536, 934634], [927992, 929949, 925379, 932272, 938180, 938146, 936203], [938180, 936711, 941149]]
# Number 935948 is in more than one sequence:  [[938180, 935948, 944648], [935948, 943865], [935948, 934876], [935948, 936907, 936908], [935948, 934766, 940350]]
# Number 938025 is in more than one sequence:  [[923025, 924541, 930978, 932328, 929830, 938025, 934524, 936219, 941655], [938025, 938785, 938393]]
# Number 926445 is in more than one sequence:  [[919565, 922278, 931115, 928572, 931680, 931788, 926445, 935186, 942991], [926445, 938576, 935065, 940722]]
# Number 942713 is in more than one sequence:  [[942713, 940190, 937639], [942713, 935046, 940629, 936956]]
# Number 941759 is in more than one sequence:  [[934318, 927787, 933193, 941759, 939877], [941759, 936294, 944400]]
# Number 931537 is in more than one sequence:  [[931537, 940337], [934326, 931537, 934675, 943565]]
# Number 940439 is in more than one sequence:  [[931655, 925082, 934365, 929884, 926592, 939541, 940439, 943502], [940439, 938071]]
# Number 927981 is in more than one sequence:  [[927981, 928372, 928579, 941970, 936180], [916484, 929930, 927981, 930480, 933287, 935339, 939639, 939796]]
# Number 941970 is in more than one sequence:  [[927981, 928372, 928579, 941970, 936180], [941970, 944683]]
# Number 936498 is in more than one sequence:  [[936498, 935085], [936498, 936835, 934437]]
# Number 925095 is in more than one sequence:  [[931832, 931594, 932664, 925095, 939885], [925095, 941283], [925095, 938759]]
# Number 936369 is in more than one sequence:  [[932707, 929969, 931603, 931746, 936369, 936942], [936369, 936370]]
# Number 935148 is in more than one sequence:  [[926104, 934860, 935148, 935473], [935148, 941681, 938856]]
# Number 932107 is in more than one sequence:  [[931417, 932107, 936875], [932107, 938160], [932107, 941420]]
# Number 929819 is in more than one sequence:  [[929819, 926836, 937102], [929819, 929709, 941116, 941724], [931810, 929819, 933439, 939588, 934415]]
# Number 941635 is in more than one sequence:  [[941635, 938805], [941635, 941896], [941635, 940730], [938494, 941635, 941636, 934706]]
# Number 934585 is in more than one sequence:  [[934585, 935651], [934585, 943959], [934585, 934943], [934585, 937081], [934585, 943223], [934585, 938666], [934585, 939790, 943634], [925055, 930965, 934585, 939979, 941683]]
# Number 939865 is in more than one sequence:  [[939865, 934687], [925502, 930939, 939865, 937278, 934550], [939865, 940624, 944145]]
# Number 929690 is in more than one sequence:  [[929690, 931006, 929041, 939033, 941617], [924544, 919999, 915930, 923959, 926633, 931862, 930273, 929690, 926850, 935793, 938392, 935454, 939892]]
# Number 926389 is in more than one sequence:  [[926389, 937755, 939472], [926389, 940715, 939642], [933430, 929386, 934091, 925538, 926389, 935945, 936306]]
# Number 934583 is in more than one sequence:  [[943706, 934583, 934910], [934583, 941438], [934583, 942901], [934583, 940374, 940428]]
# Number 941116 is in more than one sequence:  [[929819, 929709, 941116, 941724], [941116, 940431]]
# Number 926821 is in more than one sequence:  [[928103, 934177, 926797, 926821, 942249, 935484], [926821, 940356, 934462, 939207]]
# Number 936714 is in more than one sequence:  [[936714, 940187, 935519], [933855, 936714, 934504, 935013]]
# Number 940187 is in more than one sequence:  [[936714, 940187, 935519], [940187, 936277]]
# Number 929629 is in more than one sequence:  [[929629, 929129, 933668, 926545, 943483, 935341], [929629, 926659, 938439, 941805, 934957], [929629, 925105, 925574, 936978, 934499]]
# Number 940001 is in more than one sequence:  [[938255, 940001, 939792], [940001, 943623], [940001, 935735]]
# Number 936469 is in more than one sequence:  [[934782, 936469, 941855], [936469, 938507]]
# Number 938163 is in more than one sequence:  [[938163, 938607, 943392], [927098, 927804, 926727, 938163, 942535, 941473]]
# Number 925721 is in more than one sequence:  [[925721, 944377], [925721, 940849], [925721, 942721, 940241], [925721, 943950, 936836]]
# Number 941561 is in more than one sequence:  [[925256, 925586, 931751, 941561, 935712], [941561, 938256]]
# Number 941967 is in more than one sequence:  [[925883, 926647, 926648, 939544, 941967, 938968], [941967, 935461]]
# Number 929098 is in more than one sequence:  [[929098, 939834, 934777], [909262, 907344, 918328, 922271, 919246, 930119, 931466, 929098, 934912, 939844, 941055]]
# Number 943944 is in more than one sequence:  [[926499, 932036, 928392, 943944, 942387], [943944, 940129]]
# Number 941961 is in more than one sequence:  [[928246, 941961, 937182], [941961, 939572], [941961, 937436, 939709]]
# Number 929488 is in more than one sequence:  [[934244, 932562, 931125, 929488, 937072], [929488, 943842], [929488, 943698], [929488, 936161], [929488, 938560], [929488, 935044], [929488, 940845], [929488, 941772]]
# Number 935707 is in more than one sequence:  [[924289, 923027, 922476, 919204, 933409, 932353, 928164, 931572, 935707, 940478], [935707, 935708], [935707, 938433], [935707, 936664, 942424]]
# Number 942218 is in more than one sequence:  [[942218, 938580, 935869], [928246, 942218, 937883, 936387]]
# Number 938580 is in more than one sequence:  [[942218, 938580, 935869], [938580, 938243], [938580, 937207], [938580, 943451]]
# Number 931320 is in more than one sequence:  [[930274, 931320, 941242], [931320, 944187]]
# Number 938685 is in more than one sequence:  [[926940, 927275, 938685, 937932], [938685, 934473]]
# Number 939891 is in more than one sequence:  [[939891, 944512], [934759, 942515, 939891, 940228, 942722]]
# Number 939790 is in more than one sequence:  [[934585, 939790, 943634], [939790, 943077], [939790, 943750, 938367]]
# Number 936782 is in more than one sequence:  [[926467, 927993, 927120, 927334, 927531, 929782, 936794, 935978, 936782, 942731], [936782, 939984], [936782, 941809], [936782, 938863]]
# Number 934479 is in more than one sequence:  [[931103, 927669, 934479, 940839, 936171], [934479, 943328, 943819]]
# Number 934525 is in more than one sequence:  [[933647, 943306, 934525, 942697], [934525, 940440], [934525, 939543, 935677]]
# Number 937230 is in more than one sequence:  [[927270, 937230, 935544, 935036], [937230, 939900, 937129]]
# Number 943328 is in more than one sequence:  [[934479, 943328, 943819], [943328, 940889], [943328, 942294], [943328, 935589]]
# Number 926631 is in more than one sequence:  [[926631, 936857], [926631, 936684]]
# Number 935992 is in more than one sequence:  [[935992, 943061], [935992, 934717]]
# Number 936085 is in more than one sequence:  [[936085, 935940], [929202, 930237, 930300, 935109, 936085, 936532, 935632]]
# Number 931533 is in more than one sequence:  [[927593, 928421, 931533, 938609], [931533, 942084], [931533, 937313], [931533, 940810, 942185]]
# Number 939844 is in more than one sequence:  [[909262, 907344, 918328, 922271, 919246, 930119, 931466, 929098, 934912, 939844, 941055], [939844, 934563], [939844, 935158, 937020]]
# Number 937883 is in more than one sequence:  [[928246, 942218, 937883, 936387], [937883, 936168]]
# Number 929311 is in more than one sequence:  [[929311, 935396], [931162, 929311, 936865, 937726]]
# Number 934839 is in more than one sequence:  [[935650, 934839, 944109], [934839, 939019]]
# Number 942888 is in more than one sequence:  [[916996, 925722, 929788, 931566, 932934, 934009, 938894, 942888, 939866], [942888, 936362]]
# Number 931575 is in more than one sequence:  [[931810, 931592, 925873, 931575, 937799, 941411, 940706, 940002], [931575, 941690, 941990, 934593], [931575, 939342, 937141, 938470], [931575, 937574, 937532, 938915]]
# Number 936281 is in more than one sequence:  [[925967, 942097, 936281, 938019], [936281, 944325], [936281, 935960]]
# Number 940126 is in more than one sequence:  [[919200, 916388, 916297, 922785, 919014, 920211, 928338, 933152, 928417, 926921, 925282, 944108, 936558, 940126, 934408], [940126, 944564], [940126, 934594], [940126, 937467]]
# Number 934028 is in more than one sequence:  [[934247, 934028, 937139], [934028, 941319], [934028, 942257], [934028, 943890], [934028, 939079], [934028, 938546]]
# Number 932151 is in more than one sequence:  [[908358, 916870, 918442, 916324, 918063, 931787, 932279, 932293, 931707, 928662, 932151, 940950, 939634], [932151, 942232, 941879]]
# Number 927668 is in more than one sequence:  [[927668, 930297, 937296, 935863], [927668, 931668, 934444, 935604, 935645]]
# Number 942069 is in more than one sequence:  [[925357, 928269, 934112, 942069, 939150], [942069, 936676]]
# Number 941636 is in more than one sequence:  [[938494, 941635, 941636, 934706], [941636, 935993]]
# Number 944337 is in more than one sequence:  [[924861, 915920, 930821, 926002, 928161, 932009, 925655, 929258, 933892, 935139, 944337, 937500], [944337, 937581], [944337, 936215]]
# Number 937137 is in more than one sequence:  [[933489, 937137, 938963], [937137, 944378]]
# Number 943669 is in more than one sequence:  [[931117, 937950, 943669, 937539], [943669, 934568]]
# Number 940700 is in more than one sequence:  [[925764, 935262, 940700, 942175], [940700, 943486], [940700, 942391], [940700, 936470], [940700, 938079]]
# Number 936891 is in more than one sequence:  [[936891, 941978], [918234, 918441, 925577, 931373, 931160, 926435, 927242, 928111, 936992, 941251, 936891, 938141, 936086]]
# Number 937278 is in more than one sequence:  [[925502, 930939, 939865, 937278, 934550], [937278, 934979], [937278, 942131]]
# Number 943750 is in more than one sequence:  [[939790, 943750, 938367], [943750, 935333]]
# Number 942536 is in more than one sequence:  [[938180, 942491, 942536, 934634], [942536, 940254]]
# Number 939983 is in more than one sequence:  [[939983, 941316, 938918], [939983, 940934, 934520], [926420, 927713, 939983, 935427, 938947]]
# Number 933855 is in more than one sequence:  [[933855, 936714, 934504, 935013], [911999, 907622, 907914, 915987, 916969, 916973, 920604, 918181, 920891, 932164, 925644, 930815, 933855, 943740, 941117]]
# Number 937436 is in more than one sequence:  [[941961, 937436, 939709], [937436, 939008]]
# Number 939012 is in more than one sequence:  [[939012, 940763], [933526, 925134, 928497, 926153, 940096, 938359, 939012, 938644, 943532]]
# Number 934462 is in more than one sequence:  [[926821, 940356, 934462, 939207], [934462, 938577], [934462, 937916], [934462, 940701, 937178]]
# Number 925135 is in more than one sequence:  [[927751, 925135, 933423, 940699, 935426, 942245], [925135, 926641, 943887, 938290, 942236], [925135, 929301, 943844, 940269, 939804]]
# Number 930473 is in more than one sequence:  [[923656, 930473, 935578], [930473, 941824], [930473, 944533, 941095]]
# Number 935012 is in more than one sequence:  [[935012, 938267], [935012, 937827]]
# Number 940810 is in more than one sequence:  [[931533, 940810, 942185], [940810, 940811], [940810, 943592], [940810, 941755], [940810, 941426]]
# Number 943987 is in more than one sequence:  [[943987, 941006], [943987, 939382], [943987, 935346]]
# Number 926420 is in more than one sequence:  [[926420, 927713, 939983, 935427, 938947], [926420, 925967, 936276, 940617, 938027]]
# Number 944434 is in more than one sequence:  [[932321, 926967, 927017, 933854, 944434, 939766], [944434, 934769]]
# Number 942884 is in more than one sequence:  [[922556, 931923, 930438, 932779, 932603, 930773, 933621, 942884, 940693], [942884, 934423]]
# Number 935126 is in more than one sequence:  [[923803, 925114, 935126, 934783], [935126, 944246], [935126, 935323]]
# Number 937532 is in more than one sequence:  [[931575, 937574, 937532, 938915], [937532, 939904], [937532, 941999], [937532, 943351], [937532, 937973]]
# Number 936864 is in more than one sequence:  [[936864, 942150, 940991], [929815, 930632, 936864, 935135, 937446]]
# Number 943740 is in more than one sequence:  [[911999, 907622, 907914, 915987, 916969, 916973, 920604, 918181, 920891, 932164, 925644, 930815, 933855, 943740, 941117], [943740, 940651]]
# Number 934467 is in more than one sequence:  [[927682, 943114, 941976, 934467, 938276], [934467, 935362], [934467, 941412]]
# Number 940228 is in more than one sequence:  [[934759, 942515, 939891, 940228, 942722], [940228, 940645], [940228, 935794], [940228, 939564], [940228, 941546], [940228, 942856], [940228, 935002], [940228, 936251], [940228, 941502]]
# Number 938119 is in more than one sequence:  [[917308, 921429, 921016, 926133, 930574, 931904, 928537, 932969, 934546, 935089, 938119, 940625], [938119, 941219]]
# Number 935135 is in more than one sequence:  [[929815, 930632, 936864, 935135, 937446], [935135, 938763]]
# Number 943887 is in more than one sequence:  [[943887, 944605], [925135, 926641, 943887, 938290, 942236]]
# Number 936532 is in more than one sequence:  [[929202, 930237, 930300, 935109, 936085, 936532, 935632], [936532, 939658], [936532, 939632]]
# Number 943950 is in more than one sequence:  [[925721, 943950, 936836], [943950, 940267], [943950, 934700], [943950, 936185]]
# Number 942550 is in more than one sequence:  [[926130, 939355, 942550, 937362], [942550, 935476]]
# Number 937413 is in more than one sequence:  [[917716, 930763, 930780, 929922, 933145, 937413, 942128], [937413, 935332]]
# Number 939543 is in more than one sequence:  [[934525, 939543, 935677], [939543, 942517], [939543, 940325]]
# Number 939244 is in more than one sequence:  [[931117, 939244, 940903], [939244, 936015]]
# Number 935096 is in more than one sequence:  [[935096, 942394], [935096, 940605]]
# Number 939138 is in more than one sequence:  [[939138, 941440], [926766, 938883, 935644, 939138, 937819, 944399]]
# Number 939134 is in more than one sequence:  [[928686, 925043, 925756, 926165, 940294, 939134, 934728], [939134, 939242]]
# Number 935327 is in more than one sequence:  [[935327, 935252], [935327, 938345]]
# Number 940701 is in more than one sequence:  [[934462, 940701, 937178], [940701, 942532]]
# Number 935901 is in more than one sequence:  [[930362, 942111, 935901, 943760], [935901, 935408]]

# %%
# Id 12247, for example, belongs to two chains
reduced.loc[[12247, 4174]]
# Out:
#        VendorID  PULocationID  DOLocationID tpep_pickup_datetime  \
# 12247       1.0            90           249  2020-01-01 00:03:41
# 4174        1.0           249           261  2020-01-01 00:10:03
#
#       tpep_dropoff_datetime
# 12247   2020-01-01 00:10:01
# 4174    2020-01-01 00:17:14

# %%
# Check of a chain
reduced.loc[[12247, 3009]]
# Out:
#        VendorID  PULocationID  DOLocationID tpep_pickup_datetime  \
# 12247       1.0            90           249  2020-01-01 00:03:41
# 3009        1.0           249           211  2020-01-01 00:10:11
#
#       tpep_dropoff_datetime
# 12247   2020-01-01 00:10:01
# 3009    2020-01-01 00:15:43
